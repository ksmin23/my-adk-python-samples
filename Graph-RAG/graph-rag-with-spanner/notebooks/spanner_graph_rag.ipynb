# %% [markdown]
# # Spanner Graph for GraphRAG
#
# > [Spanner](https://cloud.google.com/spanner) is a highly scalable database that combines unlimited scalability with relational semantics, such as secondary indexes, strong consistency, schemas, and SQL providing 99.999% availability in one easy solution.
#
# This notebook goes over how to use `Spanner Graph` for GraphRAG with the custom retriever `SpannerGraphVectorContextRetriever` and compares the response of GraphRAG with conventional RAG.
#
# ❗This notebook is adapted from [Spanner Graph Retrievers Usage](https://github.com/googleapis/langchain-google-spanner-python/blob/main/docs/graph_rag.ipynb) with slight modifications.

# %% [markdown]
# ## 🦜🔗 Library Installation
# The integration lives in its own `langchain-google-spanner` package, so we need to install it.

# %%
# %%sh
#
# pip freeze | grep -E "langchain|spanner-graph-notebook|pydata-google-auth|pydantic"

# %%
# %%sh
# pip install -r requirements.txt

# %%
## Automatically restart kernel after installs so that your environment can access the new packages
import IPython

app = IPython.Application.instance()
app.kernel.do_shutdown(True)

# %% [markdown]
# ## 🔐 Authentication
# Authenticate to Google Cloud as the IAM user logged into this notebook in order to access your Google Cloud Project.
#
# If you are using Vertex AI Workbench, check out the setup instructions [here](https://github.com/GoogleCloudPlatform/generative-ai/tree/main/setup-env).

# %% [markdown]
# ## ☁ Set Your Google Cloud Project

# %%
PROJECT_ID = !gcloud config get project
PROJECT_ID = PROJECT_ID[0]
LOCATION = "us-central1"

PROJECT_ID, LOCATION

# %% [markdown]
# ## 💡 API Enablement
# The `langchain-google-spanner` package requires that you [enable the Spanner API](https://console.cloud.google.com/flows/enableapi?apiid=spanner.googleapis.com) in your Google Cloud Project.

# %%
# enable Spanner API
# !gcloud services enable spanner.googleapis.com

# %% [markdown]
# ## Set Spanner database values
# Find your database values, in the [Spanner Instances page](https://console.cloud.google.com/spanner?).
#
# NOTE:
#  - The database identified by INSTANCE and DATABASE must be created beforehand.
#  - The graph does NOT need to be created beforehand.
#
#    If such a graph already exists, graphs will be built atop; otherwise a new graph is automatically created.

# %%
# @title Set Your Values Here { display-mode: "form" }
INSTANCE = "graph-store-01"  # @param {type: "string"}
DATABASE = "test_graph_db"  # @param {type: "string"}
GRAPH_NAME = "retail_graph"  # @param {type: "string"}
USE_FLEXIBLE_SCHEMA = False  # @param {type: "boolean"}

# %% [markdown]
# ## SpannerGraphStore
#
# To initialize the `SpannerGraphStore` class you need to provide 3 required arguments and other arguments are optional and only need to pass if it's different from default ones
#
# 1.   a Spanner instance id
# 2.   a Spanner database id belongs to the above instance id
# 3.   a Spanner graph name used to create a graph in the above database.

# %%
from langchain_google_spanner import SpannerGraphStore

graph_store = SpannerGraphStore(
    instance_id=INSTANCE,
    database_id=DATABASE,
    graph_name=GRAPH_NAME
)

# %% [markdown]
# ## Add Graph Documents
# To add graph documents in the graph store.

# %% [markdown]
# ### Load Documents

# %%
# !wget https://raw.githubusercontent.com/googleapis/langchain-google-spanner-python/main/samples/retaildata.zip -P content
# !unzip "content/retaildata.zip" -d content

# %%
import os
from langchain_community.document_loaders import DirectoryLoader
from langchain_community.document_loaders import TextLoader
from langchain_core.documents import Document

path = "content/retaildata/"
directories = [
    item for item in os.listdir(path) if os.path.isdir(os.path.join(path, item))
]

document_lists = []
for directory in directories:
    loader = DirectoryLoader(
        os.path.join(path, directory), glob="**/*.txt", loader_cls=TextLoader
    )
    document_lists.append(loader.load())

# %%
len(document_lists)

# %% [markdown]
# ### Extract Nodes and Edges

# %%
from langchain_experimental.graph_transformers import LLMGraphTransformer
from langchain_google_vertexai import ChatVertexAI, VertexAIEmbeddings

# llm = VertexAI(model_name="gemini-2.5-flash")
# ValueError: The 'node_properties' and 'relationship_properties' parameters cannot be used in combination with a LLM that doesn't support native function calling.
llm = ChatVertexAI(model="gemini-2.5-flash", temperature=0)
llm_transformer = LLMGraphTransformer(
    llm=llm,
    allowed_nodes=["Category", "Segment", "Tag", "Product", "Bundle", "Deal"],
    allowed_relationships=[
        "In_Category",
        "Tagged_With",
        "In_Segment",
        "In_Bundle",
        "Is_Accessory_Of",
        "Is_Upgrade_Of",
        "Has_Deal",
    ],
    node_properties=[
        "name",
        "price",
        "weight",
        "deal_end_date",
        "features",
    ],
)

# %%
graph_documents = []
for document_list in document_lists:
    graph_documents.extend(llm_transformer.convert_to_graph_documents(document_list))

# %%
len(graph_documents)

# %%
# Add embeddings to the graph documents for Product nodes
embedding_service = VertexAIEmbeddings(model_name="text-embedding-005")
for graph_document in graph_documents:
    for node in graph_document.nodes:
        if "features" in node.properties:
            node.properties["embedding"] = embedding_service.embed_query(
                node.properties["features"]
            )

# %%
import copy

def print_graph(graph_documents):
    for doc in graph_documents:
        print(f"{doc.source.page_content[:100]} === truncated ===")
        nodes = copy.deepcopy(doc.nodes)
        for node in nodes:
            if "embedding" in node.properties:
                node.properties["embedding"] = "..."
        print(nodes)
        print(doc.relationships)
        print()

# %%
print_graph(graph_documents)
# Out:
#  **QuantumLeap Flash Friday Deal - Unleash Blazing Fast Storage!**
#
# **Price:** $39.99
#
# **Manufactur === truncated ===
# [Node(id='Quantumleap Flash Friday Deal', type='Deal', properties={'deal_end_date': '2024-03-01'}), Node(id='Quantumleap Flash Drive', type='Product', properties={'price': '39.99'}), Node(id='Quantumstorage Technologies', type='Product', properties={'name': 'QuantumStorage Technologies'}), Node(id='Storage', type='Tag', properties={}), Node(id='Data', type='Tag', properties={})]
# [Relationship(source=Node(id='Quantumleap Flash Drive', type='Product', properties={}), target=Node(id='Quantumleap Flash Friday Deal', type='Deal', properties={}), type='HAS_DEAL', properties={}), Relationship(source=Node(id='Quantumleap Flash Drive', type='Product', properties={}), target=Node(id='Storage', type='Tag', properties={}), type='TAGGED_WITH', properties={}), Relationship(source=Node(id='Quantumleap Flash Drive', type='Product', properties={}), target=Node(id='Data', type='Tag', properties={}), type='TAGGED_WITH', properties={})]
#
#
#  DataSafe Vault
#
# Price: $39.99
#
# Manufacturer: SecureTech Solutions
#
# Description: Keep your sensitiv === truncated ===
# [Node(id='Datasafe Vault', type='Product', properties={'price': '39.99'}), Node(id='Securetech Solutions', type='Segment', properties={'name': 'SecureTech Solutions'}), Node(id='Storage', type='Tag', properties={}), Node(id='Data', type='Tag', properties={}), Node(id='Titandrive X5000', type='Product', properties={})]
# [Relationship(source=Node(id='Datasafe Vault', type='Product', properties={}), target=Node(id='Securetech Solutions', type='Segment', properties={}), type='IN_SEGMENT', properties={}), Relationship(source=Node(id='Datasafe Vault', type='Product', properties={}), target=Node(id='Storage', type='Tag', properties={}), type='TAGGED_WITH', properties={}), Relationship(source=Node(id='Datasafe Vault', type='Product', properties={}), target=Node(id='Data', type='Tag', properties={}), type='TAGGED_WITH', properties={}), Relationship(source=Node(id='Datasafe Vault', type='Product', properties={}), target=Node(id='Titandrive X5000', type='Product', properties={}), type='IS_ACCESSORY_OF', properties={})]
#
#
#  QuantumLeap Ultimate Kit
#
# Price: $64.99
#
# Manufacturer: QuantumLeap Technologies
#
# Description: Unle === truncated ===
# [Node(id='Quantumleap Ultimate Kit', type='Bundle', properties={'price': '64.99'}), Node(id='Quantumleap Flash Drive', type='Product', properties={}), Node(id='Universal Adapter Kit', type='Product', properties={}), Node(id='Quantumleap Technologies', type='Category', properties={}), Node(id='Storage', type='Tag', properties={}), Node(id='Data', type='Tag', properties={})]
# [Relationship(source=Node(id='Quantumleap Ultimate Kit', type='Bundle', properties={}), target=Node(id='Quantumleap Flash Drive', type='Product', properties={}), type='IN_BUNDLE', properties={}), Relationship(source=Node(id='Quantumleap Ultimate Kit', type='Bundle', properties={}), target=Node(id='Universal Adapter Kit', type='Product', properties={}), type='IN_BUNDLE', properties={}), Relationship(source=Node(id='Quantumleap Ultimate Kit', type='Bundle', properties={}), target=Node(id='Storage', type='Tag', properties={}), type='TAGGED_WITH', properties={}), Relationship(source=Node(id='Quantumleap Ultimate Kit', type='Bundle', properties={}), target=Node(id='Data', type='Tag', properties={}), type='TAGGED_WITH', properties={})]
#
#
#  Product Summary: QuantumLeap Flash
#
# Blazing-fast storage in a sleek, retractable design. The Quant === truncated ===
# [Node(id='Quantumleap Flash', type='Product', properties={'price': '49.99', 'features': 'LED Activity Indicator', 'embedding': '...'}), Node(id='Usb Flash Drive', type='Category', properties={}), Node(id='Home', type='Segment', properties={}), Node(id='Office', type='Segment', properties={}), Node(id='Storage', type='Tag', properties={}), Node(id='Data', type='Tag', properties={}), Node(id='Universal Adapter Kit', type='Product', properties={})]
# [Relationship(source=Node(id='Quantumleap Flash', type='Product', properties={}), target=Node(id='Usb Flash Drive', type='Category', properties={}), type='IN_CATEGORY', properties={}), Relationship(source=Node(id='Quantumleap Flash', type='Product', properties={}), target=Node(id='Home', type='Segment', properties={}), type='IN_SEGMENT', properties={}), Relationship(source=Node(id='Quantumleap Flash', type='Product', properties={}), target=Node(id='Office', type='Segment', properties={}), type='IN_SEGMENT', properties={}), Relationship(source=Node(id='Quantumleap Flash', type='Product', properties={}), target=Node(id='Storage', type='Tag', properties={}), type='TAGGED_WITH', properties={}), Relationship(source=Node(id='Quantumleap Flash', type='Product', properties={}), target=Node(id='Data', type='Tag', properties={}), type='TAGGED_WITH', properties={}), Relationship(source=Node(id='Universal Adapter Kit', type='Product', properties={}), target=Node(id='Quantumleap Flash', type='Product', properties={}), type='IS_ACCESSORY_OF', properties={})]
#
#
#  Product Summary: Secure Erase Tool
#
# Price: $9.99
#
# Description: Ensure your sensitive data is perma === truncated ===
# [Node(id='Secure Erase Tool', type='Product', properties={'price': '9.99'}), Node(id='Datasafe Solutions', type='Category', properties={'name': 'DataSafe Solutions'}), Node(id='Titandrive X5000', type='Product', properties={}), Node(id='Quantumleap Flash', type='Product', properties={}), Node(id='Storage', type='Tag', properties={}), Node(id='Data', type='Tag', properties={})]
# [Relationship(source=Node(id='Secure Erase Tool', type='Product', properties={}), target=Node(id='Datasafe Solutions', type='Category', properties={}), type='IN_CATEGORY', properties={}), Relationship(source=Node(id='Secure Erase Tool', type='Product', properties={}), target=Node(id='Titandrive X5000', type='Product', properties={}), type='IS_ACCESSORY_OF', properties={}), Relationship(source=Node(id='Secure Erase Tool', type='Product', properties={}), target=Node(id='Quantumleap Flash', type='Product', properties={}), type='IS_ACCESSORY_OF', properties={}), Relationship(source=Node(id='Secure Erase Tool', type='Product', properties={}), target=Node(id='Storage', type='Tag', properties={}), type='TAGGED_WITH', properties={}), Relationship(source=Node(id='Secure Erase Tool', type='Product', properties={}), target=Node(id='Data', type='Tag', properties={}), type='TAGGED_WITH', properties={})]
#
#
#  Product Summary: Universal Adapter Kit
#
# Effortlessly connect your devices with the Universal Adapt === truncated ===
# [Node(id='Universal Adapter Kit', type='Product', properties={'price': '19.99', 'weight': '0.8 oz', 'features': 'Durable Construction: Built to withstand daily use.', 'embedding': '...'}), Node(id='Quantumleap Flash Drive', type='Product', properties={}), Node(id='Storage', type='Tag', properties={}), Node(id='Data', type='Tag', properties={})]
# [Relationship(source=Node(id='Universal Adapter Kit', type='Product', properties={}), target=Node(id='Quantumleap Flash Drive', type='Product', properties={}), type='IS_ACCESSORY_OF', properties={}), Relationship(source=Node(id='Universal Adapter Kit', type='Product', properties={}), target=Node(id='Storage', type='Tag', properties={}), type='TAGGED_WITH', properties={}), Relationship(source=Node(id='Universal Adapter Kit', type='Product', properties={}), target=Node(id='Data', type='Tag', properties={}), type='TAGGED_WITH', properties={})]
#
#
#  TitanDrive X5000 Backup Bundle - Safeguard Your Data
#
# Price: $329.99
#
# Manufacturer: TitanDrive
#
# De === truncated ===
# [Node(id='Titandrive X5000 Backup Bundle', type='Bundle', properties={'price': '329.99'}), Node(id='Titandrive X5000', type='Product', properties={'name': 'TitanDrive X5000', 'weight': '8 ounces'}), Node(id='Secure Erase Tool', type='Product', properties={'name': 'Secure Erase Tool'}), Node(id='Storage', type='Tag', properties={}), Node(id='Data', type='Tag', properties={})]
# [Relationship(source=Node(id='Titandrive X5000 Backup Bundle', type='Bundle', properties={}), target=Node(id='Titandrive X5000', type='Product', properties={}), type='IN_BUNDLE', properties={}), Relationship(source=Node(id='Titandrive X5000 Backup Bundle', type='Bundle', properties={}), target=Node(id='Secure Erase Tool', type='Product', properties={}), type='IN_BUNDLE', properties={}), Relationship(source=Node(id='Titandrive X5000 Backup Bundle', type='Bundle', properties={}), target=Node(id='Storage', type='Tag', properties={}), type='TAGGED_WITH', properties={}), Relationship(source=Node(id='Titandrive X5000 Backup Bundle', type='Bundle', properties={}), target=Node(id='Data', type='Tag', properties={}), type='TAGGED_WITH', properties={})]
#
#
#  **Product Summary: TitanDrive X5000 - 5TB Ruggedized External SSD**
#
# Unleash unparalleled speed an === truncated ===
# [Node(id='Titandrive X5000', type='Product', properties={'price': '299.99', 'weight': '119 g', 'features': 'Extreme Speed, Ruggedized Design, Massive Storage, Universal Compatibility, Compact and Portable, DataSafe Vault Compatible', 'embedding': '...'}), Node(id='External Hard Drive', type='Category', properties={}), Node(id='Home', type='Segment', properties={}), Node(id='Office', type='Segment', properties={}), Node(id='Storage', type='Tag', properties={}), Node(id='Data', type='Tag', properties={}), Node(id='Titandrive X4000', type='Product', properties={})]
# [Relationship(source=Node(id='Titandrive X5000', type='Product', properties={}), target=Node(id='External Hard Drive', type='Category', properties={}), type='IN_CATEGORY', properties={}), Relationship(source=Node(id='Titandrive X5000', type='Product', properties={}), target=Node(id='Home', type='Segment', properties={}), type='IN_SEGMENT', properties={}), Relationship(source=Node(id='Titandrive X5000', type='Product', properties={}), target=Node(id='Office', type='Segment', properties={}), type='IN_SEGMENT', properties={}), Relationship(source=Node(id='Titandrive X5000', type='Product', properties={}), target=Node(id='Storage', type='Tag', properties={}), type='TAGGED_WITH', properties={}), Relationship(source=Node(id='Titandrive X5000', type='Product', properties={}), target=Node(id='Data', type='Tag', properties={}), type='TAGGED_WITH', properties={}), Relationship(source=Node(id='Titandrive X5000', type='Product', properties={}), target=Node(id='Titandrive X4000', type='Product', properties={}), type='IS_UPGRADE_OF', properties={})]
#
#
# Product Summary: Quantum Shield Screen Protector
#
# Protect your Aura X5 or Aura X5 Pro with the Quan === truncated ===
# [Node(id='Quantum Shield Screen Protector', type='Product', properties={'price': '19', 'features': 'Easy to clean', 'embedding': '...'}), Node(id='Aura X5', type='Product', properties={}), Node(id='Aura X5 Pro', type='Product', properties={}), Node(id='Screen Guards', type='Category', properties={}), Node(id='Home', type='Segment', properties={}), Node(id='Phone', type='Tag', properties={})]
# [Relationship(source=Node(id='Quantum Shield Screen Protector', type='Product', properties={}), target=Node(id='Aura X5', type='Product', properties={}), type='IS_ACCESSORY_OF', properties={}), Relationship(source=Node(id='Quantum Shield Screen Protector', type='Product', properties={}), target=Node(id='Aura X5 Pro', type='Product', properties={}), type='IS_ACCESSORY_OF', properties={}), Relationship(source=Node(id='Quantum Shield Screen Protector', type='Product', properties={}), target=Node(id='Screen Guards', type='Category', properties={}), type='IN_CATEGORY', properties={}), Relationship(source=Node(id='Quantum Shield Screen Protector', type='Product', properties={}), target=Node(id='Home', type='Segment', properties={}), type='IN_SEGMENT', properties={}), Relationship(source=Node(id='Quantum Shield Screen Protector', type='Product', properties={}), target=Node(id='Phone', type='Tag', properties={}), type='TAGGED_WITH', properties={})]
#
#
# Product Summary: Aura X5 Pro - Capture Brilliance, Last Longer
#
# Price: $1299.00
#
# Manufacturer: Aura === truncated ===
# [Node(id='Aura X5 Pro', type='Product', properties={'price': '1299.00'}), Node(id='Aura X5', type='Product', properties={}), Node(id='Aura X5 Case', type='Product', properties={}), Node(id='Mobile Phones', type='Category', properties={}), Node(id='Home', type='Segment', properties={}), Node(id='Phone', type='Tag', properties={})]
# [Relationship(source=Node(id='Aura X5 Pro', type='Product', properties={}), target=Node(id='Aura X5', type='Product', properties={}), type='IS_UPGRADE_OF', properties={}), Relationship(source=Node(id='Aura X5 Pro', type='Product', properties={}), target=Node(id='Aura X5 Case', type='Product', properties={}), type='IS_ACCESSORY_OF', properties={}), Relationship(source=Node(id='Aura X5 Pro', type='Product', properties={}), target=Node(id='Mobile Phones', type='Category', properties={}), type='IN_CATEGORY', properties={}), Relationship(source=Node(id='Aura X5 Pro', type='Product', properties={}), target=Node(id='Home', type='Segment', properties={}), type='IN_SEGMENT', properties={}), Relationship(source=Node(id='Aura X5 Pro', type='Product', properties={}), target=Node(id='Phone', type='Tag', properties={}), type='TAGGED_WITH', properties={})]
#
#
# Product Summary: Sonaris Pro Charging Stand
#
# Price: $29.00
#
# Manufacturer: Sonaris Audio
#
# Descriptio === truncated ===
# [Node(id='Sonaris Pro Charging Stand', type='Product', properties={'price': '29.00'}), Node(id='Accessories', type='Category', properties={}), Node(id='Home', type='Segment', properties={}), Node(id='Phone', type='Tag', properties={})]
# [Relationship(source=Node(id='Sonaris Pro Charging Stand', type='Product', properties={}), target=Node(id='Accessories', type='Category', properties={}), type='IN_CATEGORY', properties={}), Relationship(source=Node(id='Sonaris Pro Charging Stand', type='Product', properties={}), target=Node(id='Home', type='Segment', properties={}), type='IN_SEGMENT', properties={}), Relationship(source=Node(id='Sonaris Pro Charging Stand', type='Product', properties={}), target=Node(id='Phone', type='Tag', properties={}), type='TAGGED_WITH', properties={})]
#
#
# Product Summary: Sonaris Pro Noise-Canceling Headphones
#
# Immerse yourself in pristine audio with th === truncated ===
# [Node(id='Sonaris Pro Noise-Canceling Headphones', type='Product', properties={'price': '249.00', 'features': 'Intuitive Controls', 'weight': '0.6 lbs', 'embedding': '...'}), Node(id='Headphones', type='Category', properties={}), Node(id='Home', type='Segment', properties={}), Node(id='Phone', type='Tag', properties={}), Node(id='Sonaris Pro Charging Stand', type='Product', properties={})]
# [Relationship(source=Node(id='Sonaris Pro Noise-Canceling Headphones', type='Product', properties={}), target=Node(id='Headphones', type='Category', properties={}), type='IN_CATEGORY', properties={}), Relationship(source=Node(id='Sonaris Pro Noise-Canceling Headphones', type='Product', properties={}), target=Node(id='Home', type='Segment', properties={}), type='IN_SEGMENT', properties={}), Relationship(source=Node(id='Sonaris Pro Noise-Canceling Headphones', type='Product', properties={}), target=Node(id='Phone', type='Tag', properties={}), type='TAGGED_WITH', properties={}), Relationship(source=Node(id='Sonaris Pro Noise-Canceling Headphones', type='Product', properties={}), target=Node(id='Sonaris Pro Charging Stand', type='Product', properties={}), type='IS_ACCESSORY_OF', properties={})]
#
#
#  Sonaris Max: Over-Ear Headphones - Experience Superior Sound
#
# Price: $349.00
#
# Manufacturer: Sonari === truncated ===
# [Node(id='Sonaris Max', type='Product', properties={'price': '349.00', 'features': 'Foldable design', 'weight': '9.9 ounces', 'embedding': '...'}), Node(id='Headphones', type='Category', properties={}), Node(id='Home', type='Segment', properties={}), Node(id='Phone', type='Tag', properties={}), Node(id='Sonaris Pro Charging Stand', type='Product', properties={}), Node(id='Headphone Cleaning Kit', type='Product', properties={})]
# [Relationship(source=Node(id='Sonaris Max', type='Product', properties={}), target=Node(id='Headphones', type='Category', properties={}), type='IN_CATEGORY', properties={}), Relationship(source=Node(id='Sonaris Max', type='Product', properties={}), target=Node(id='Home', type='Segment', properties={}), type='IN_SEGMENT', properties={}), Relationship(source=Node(id='Sonaris Max', type='Product', properties={}), target=Node(id='Phone', type='Tag', properties={}), type='TAGGED_WITH', properties={}), Relationship(source=Node(id='Sonaris Max', type='Product', properties={}), target=Node(id='Sonaris Pro Charging Stand', type='Product', properties={}), type='IS_ACCESSORY_OF', properties={}), Relationship(source=Node(id='Sonaris Max', type='Product', properties={}), target=Node(id='Headphone Cleaning Kit', type='Product', properties={}), type='IS_ACCESSORY_OF', properties={})]
#
#
# **Summer Sale! Get Aura X5 + Quantum Shield at a Discount!**
#
# **Price:** $875.00
#
# **Manufacturer:** === truncated ===
# [Node(id='Aura X5', type='Product', properties={'name': 'Aura X5'}), Node(id='Quantum Shield', type='Product', properties={'name': 'Quantum Shield'}), Node(id='Summer Sale', type='Deal', properties={'deal_end_date': '2024-07-31', 'price': '875.00'}), Node(id='Deals', type='Category', properties={}), Node(id='Home', type='Segment', properties={}), Node(id='Phone', type='Tag', properties={})]
# [Relationship(source=Node(id='Aura X5', type='Product', properties={}), target=Node(id='Summer Sale', type='Deal', properties={}), type='HAS_DEAL', properties={}), Relationship(source=Node(id='Quantum Shield', type='Product', properties={}), target=Node(id='Summer Sale', type='Deal', properties={}), type='HAS_DEAL', properties={}), Relationship(source=Node(id='Summer Sale', type='Deal', properties={}), target=Node(id='Deals', type='Category', properties={}), type='IN_CATEGORY', properties={}), Relationship(source=Node(id='Summer Sale', type='Deal', properties={}), target=Node(id='Home', type='Segment', properties={}), type='IN_SEGMENT', properties={}), Relationship(source=Node(id='Summer Sale', type='Deal', properties={}), target=Node(id='Phone', type='Tag', properties={}), type='TAGGED_WITH', properties={})]
#
#
# **Product Summary: Audio Lover's Bundle**
#
# Immerse yourself in a world of unparalleled audio fideli === truncated ===
# [Node(id="Audio Lover'S Bundle", type='Bundle', properties={'price': '550'}), Node(id='Sonaris Pro Headphones', type='Product', properties={'name': 'headphones'}), Node(id='Sonaris Pro Charging Stand', type='Product', properties={'name': 'charging stand'}), Node(id='Headphone Cleaning Kit', type='Product', properties={'name': 'cleaning kit'}), Node(id='Bundles', type='Category', properties={}), Node(id='Home', type='Segment', properties={}), Node(id='Phone', type='Tag', properties={})]
# [Relationship(source=Node(id="Audio Lover'S Bundle", type='Bundle', properties={}), target=Node(id='Sonaris Pro Headphones', type='Product', properties={}), type='IN_BUNDLE', properties={}), Relationship(source=Node(id="Audio Lover'S Bundle", type='Bundle', properties={}), target=Node(id='Sonaris Pro Charging Stand', type='Product', properties={}), type='IN_BUNDLE', properties={}), Relationship(source=Node(id="Audio Lover'S Bundle", type='Bundle', properties={}), target=Node(id='Headphone Cleaning Kit', type='Product', properties={}), type='IN_BUNDLE', properties={}), Relationship(source=Node(id="Audio Lover'S Bundle", type='Bundle', properties={}), target=Node(id='Bundles', type='Category', properties={}), type='IN_CATEGORY', properties={}), Relationship(source=Node(id="Audio Lover'S Bundle", type='Bundle', properties={}), target=Node(id='Home', type='Segment', properties={}), type='IN_SEGMENT', properties={}), Relationship(source=Node(id="Audio Lover'S Bundle", type='Bundle', properties={}), target=Node(id='Phone', type='Tag', properties={}), type='TAGGED_WITH', properties={})]
#
#
# Sonaris Max: Over-Ear Headphones - Experience Superior Sound
#
# Price: $349.00
#
# Manufacturer: Sonaris === truncated ===
# [Node(id='Sonaris Max', type='Product', properties={'price': '349.00', 'features': 'Foldable design for easy storage and portability', 'weight': '9.9 ounces', 'embedding': '...'}), Node(id='Headphones', type='Category', properties={}), Node(id='Home', type='Segment', properties={}), Node(id='Phone', type='Tag', properties={}), Node(id='Sonaris Pro Charging Stand', type='Product', properties={}), Node(id='Headphone Cleaning Kit', type='Product', properties={})]
# [Relationship(source=Node(id='Sonaris Max', type='Product', properties={}), target=Node(id='Headphones', type='Category', properties={}), type='IN_CATEGORY', properties={}), Relationship(source=Node(id='Sonaris Max', type='Product', properties={}), target=Node(id='Home', type='Segment', properties={}), type='IN_SEGMENT', properties={}), Relationship(source=Node(id='Sonaris Max', type='Product', properties={}), target=Node(id='Phone', type='Tag', properties={}), type='TAGGED_WITH', properties={}), Relationship(source=Node(id='Sonaris Pro Charging Stand', type='Product', properties={}), target=Node(id='Sonaris Max', type='Product', properties={}), type='IS_ACCESSORY_OF', properties={}), Relationship(source=Node(id='Headphone Cleaning Kit', type='Product', properties={}), target=Node(id='Sonaris Max', type='Product', properties={}), type='IS_ACCESSORY_OF', properties={})]
#
#
#  Aura X5 Case
#
# Price: $39.00
#
# Manufacturer: Aura Accessories
#
# Description: Protect your Aura X5 or  === truncated ===
# [Node(id='Aura X5 Case', type='Product', properties={'price': '39.00', 'weight': '1.5 ounces'}), Node(id='Aura X5', type='Product', properties={}), Node(id='Aura X5 Pro', type='Product', properties={}), Node(id='Cases', type='Category', properties={}), Node(id='Home', type='Segment', properties={}), Node(id='Phone', type='Tag', properties={})]
# [Relationship(source=Node(id='Aura X5 Case', type='Product', properties={}), target=Node(id='Aura X5', type='Product', properties={}), type='IS_ACCESSORY_OF', properties={}), Relationship(source=Node(id='Aura X5 Case', type='Product', properties={}), target=Node(id='Aura X5 Pro', type='Product', properties={}), type='IS_ACCESSORY_OF', properties={}), Relationship(source=Node(id='Aura X5 Case', type='Product', properties={}), target=Node(id='Cases', type='Category', properties={}), type='IN_CATEGORY', properties={}), Relationship(source=Node(id='Aura X5 Case', type='Product', properties={}), target=Node(id='Home', type='Segment', properties={}), type='IN_SEGMENT', properties={}), Relationship(source=Node(id='Aura X5 Case', type='Product', properties={}), target=Node(id='Phone', type='Tag', properties={}), type='TAGGED_WITH', properties={})]
#
#
# **Product Summary: Aura X5 Starter Kit**
#
# **Description:** Get started with the revolutionary Aura  === truncated ===
# [Node(id='Aura X5 Starter Kit', type='Bundle', properties={'price': '920.00'}), Node(id='Aura X5', type='Product', properties={}), Node(id='Aura X5 Case', type='Product', properties={}), Node(id='Quantum Shield', type='Product', properties={}), Node(id='Bundles', type='Category', properties={}), Node(id='Home', type='Segment', properties={}), Node(id='Phone', type='Tag', properties={})]
# [Relationship(source=Node(id='Aura X5 Starter Kit', type='Bundle', properties={}), target=Node(id='Aura X5', type='Product', properties={}), type='IN_BUNDLE', properties={}), Relationship(source=Node(id='Aura X5 Starter Kit', type='Bundle', properties={}), target=Node(id='Aura X5 Case', type='Product', properties={}), type='IN_BUNDLE', properties={}), Relationship(source=Node(id='Aura X5 Starter Kit', type='Bundle', properties={}), target=Node(id='Quantum Shield', type='Product', properties={}), type='IN_BUNDLE', properties={}), Relationship(source=Node(id='Aura X5 Starter Kit', type='Bundle', properties={}), target=Node(id='Bundles', type='Category', properties={}), type='IN_CATEGORY', properties={}), Relationship(source=Node(id='Aura X5 Starter Kit', type='Bundle', properties={}), target=Node(id='Home', type='Segment', properties={}), type='IN_SEGMENT', properties={}), Relationship(source=Node(id='Aura X5 Starter Kit', type='Bundle', properties={}), target=Node(id='Phone', type='Tag', properties={}), type='TAGGED_WITH', properties={})]
#
# ,
# Product Summary: Aura X5 Smartphone
#
# Experience the future of mobile technology with the Aura X5.  === truncated ===
# [Node(id='Aura X5 Smartphone', type='Product', properties={'price': '899.00', 'features': 'Long-lasting Battery', 'weight': '205g', 'embedding': '...'}), Node(id='Aura X5 Case', type='Product', properties={}), Node(id='Mobile Phones', type='Category', properties={}), Node(id='Home', type='Segment', properties={}), Node(id='Phone', type='Tag', properties={})]
# [Relationship(source=Node(id='Aura X5 Smartphone', type='Product', properties={}), target=Node(id='Aura X5 Case', type='Product', properties={}), type='IS_ACCESSORY_OF', properties={}), Relationship(source=Node(id='Aura X5 Smartphone', type='Product', properties={}), target=Node(id='Mobile Phones', type='Category', properties={}), type='IN_CATEGORY', properties={}), Relationship(source=Node(id='Aura X5 Smartphone', type='Product', properties={}), target=Node(id='Home', type='Segment', properties={}), type='IN_SEGMENT', properties={}), Relationship(source=Node(id='Aura X5 Smartphone', type='Product', properties={}), target=Node(id='Phone', type='Tag', properties={}), type='TAGGED_WITH', properties={})]
#
#
#   Limited-Time Offer: SkyHawk Zephyr Propeller Guards
#   Fly with Confidence & Save!
#   Deal Price: $ === truncated ===
# [Node(id='Skyhawk Zephyr Propeller Guards', type='Product', properties={}), Node(id='Photography', type='Tag', properties={}), Node(id='Videography', type='Tag', properties={}), Node(id='Limited-Time Offer: Skyhawk Zephyr Propeller Guards', type='Deal', properties={'price': '9.99', 'deal_end_date': '2025-05-31'})]
# [Relationship(source=Node(id='Skyhawk Zephyr Propeller Guards', type='Product', properties={}), target=Node(id='Photography', type='Tag', properties={}), type='TAGGED_WITH', properties={}), Relationship(source=Node(id='Skyhawk Zephyr Propeller Guards', type='Product', properties={}), target=Node(id='Videography', type='Tag', properties={}), type='TAGGED_WITH', properties={}), Relationship(source=Node(id='Skyhawk Zephyr Propeller Guards', type='Product', properties={}), target=Node(id='Limited-Time Offer: Skyhawk Zephyr Propeller Guards', type='Deal', properties={}), type='HAS_DEAL', properties={})]
#
#
#   Bunde: SkyHawk Zephyr Explorer Package
#   Price: $179.99
#   Enhance your flight experience with add === truncated ===
# [Node(id='Skyhawk Zephyr Explorer Package', type='Bundle', properties={'price': '179.99'}), Node(id='Skyhawk Zephyr Drone', type='Product', properties={}), Node(id='Remote Controller', type='Product', properties={}), Node(id='Rechargeable Battery + Extended Battery', type='Product', properties={}), Node(id='Usb Charging Cable', type='Product', properties={}), Node(id='Spare Propellers', type='Product', properties={}), Node(id='Propeller Guards', type='Product', properties={}), Node(id='User Manual', type='Product', properties={}), Node(id='Carrying Case', type='Product', properties={}), Node(id='Photography', type='Tag', properties={}), Node(id='Videography', type='Tag', properties={})]
# [Relationship(source=Node(id='Skyhawk Zephyr Explorer Package', type='Bundle', properties={}), target=Node(id='Skyhawk Zephyr Drone', type='Product', properties={}), type='IN_BUNDLE', properties={}), Relationship(source=Node(id='Skyhawk Zephyr Explorer Package', type='Bundle', properties={}), target=Node(id='Remote Controller', type='Product', properties={}), type='IN_BUNDLE', properties={}), Relationship(source=Node(id='Skyhawk Zephyr Explorer Package', type='Bundle', properties={}), target=Node(id='Rechargeable Battery + Extended Battery', type='Product', properties={}), type='IN_BUNDLE', properties={}), Relationship(source=Node(id='Skyhawk Zephyr Explorer Package', type='Bundle', properties={}), target=Node(id='Usb Charging Cable', type='Product', properties={}), type='IN_BUNDLE', properties={}), Relationship(source=Node(id='Skyhawk Zephyr Explorer Package', type='Bundle', properties={}), target=Node(id='Spare Propellers', type='Product', properties={}), type='IN_BUNDLE', properties={}), Relationship(source=Node(id='Skyhawk Zephyr Explorer Package', type='Bundle', properties={}), target=Node(id='Propeller Guards', type='Product', properties={}), type='IN_BUNDLE', properties={}), Relationship(source=Node(id='Skyhawk Zephyr Explorer Package', type='Bundle', properties={}), target=Node(id='User Manual', type='Product', properties={}), type='IN_BUNDLE', properties={}), Relationship(source=Node(id='Skyhawk Zephyr Explorer Package', type='Bundle', properties={}), target=Node(id='Carrying Case', type='Product', properties={}), type='IN_BUNDLE', properties={}), Relationship(source=Node(id='Skyhawk Zephyr Explorer Package', type='Bundle', properties={}), target=Node(id='Photography', type='Tag', properties={}), type='TAGGED_WITH', properties={}), Relationship(source=Node(id='Skyhawk Zephyr Explorer Package', type='Bundle', properties={}), target=Node(id='Videography', type='Tag', properties={}), type='TAGGED_WITH', properties={})]
#
#
#   Limited-Time Offer: SkyHawk Zephyr Drone
#   Save on your first drone
#   Deal Price: $109.99  (Origi === truncated ===
# [Node(id='Skyhawk Zephyr Drone', type='Product', properties={'price': '109.99'}), Node(id='Photography', type='Tag', properties={}), Node(id='Videography', type='Tag', properties={}), Node(id='Limited-Time Offer: Skyhawk Zephyr Drone', type='Deal', properties={'deal_end_date': '2025-05-31'})]
# [Relationship(source=Node(id='Skyhawk Zephyr Drone', type='Product', properties={}), target=Node(id='Photography', type='Tag', properties={}), type='TAGGED_WITH', properties={}), Relationship(source=Node(id='Skyhawk Zephyr Drone', type='Product', properties={}), target=Node(id='Videography', type='Tag', properties={}), type='TAGGED_WITH', properties={}), Relationship(source=Node(id='Skyhawk Zephyr Drone', type='Product', properties={}), target=Node(id='Limited-Time Offer: Skyhawk Zephyr Drone', type='Deal', properties={}), type='HAS_DEAL', properties={})]
#
#
#   Bundle:SkyHawk Zephyr Starter Package
#   Price: $129.99
#   Everything you need to begin your drone  === truncated ===
# [Node(id='Skyhawk Zephyr Starter Package', type='Bundle', properties={'price': '129.99'}), Node(id='Skyhawk Zephyr Drone', type='Product', properties={}), Node(id='Remote Controller', type='Product', properties={}), Node(id='Rechargeable Battery', type='Product', properties={}), Node(id='Usb Charging Cable', type='Product', properties={}), Node(id='Spare Propellers', type='Product', properties={}), Node(id='User Manual', type='Product', properties={}), Node(id='Photography', type='Tag', properties={}), Node(id='Videography', type='Tag', properties={})]
# [Relationship(source=Node(id='Skyhawk Zephyr Starter Package', type='Bundle', properties={}), target=Node(id='Skyhawk Zephyr Drone', type='Product', properties={}), type='IN_BUNDLE', properties={}), Relationship(source=Node(id='Skyhawk Zephyr Starter Package', type='Bundle', properties={}), target=Node(id='Remote Controller', type='Product', properties={}), type='IN_BUNDLE', properties={}), Relationship(source=Node(id='Skyhawk Zephyr Starter Package', type='Bundle', properties={}), target=Node(id='Rechargeable Battery', type='Product', properties={}), type='IN_BUNDLE', properties={}), Relationship(source=Node(id='Skyhawk Zephyr Starter Package', type='Bundle', properties={}), target=Node(id='Usb Charging Cable', type='Product', properties={}), type='IN_BUNDLE', properties={}), Relationship(source=Node(id='Skyhawk Zephyr Starter Package', type='Bundle', properties={}), target=Node(id='Spare Propellers', type='Product', properties={}), type='IN_BUNDLE', properties={}), Relationship(source=Node(id='Skyhawk Zephyr Starter Package', type='Bundle', properties={}), target=Node(id='User Manual', type='Product', properties={}), type='IN_BUNDLE', properties={}), Relationship(source=Node(id='Skyhawk Zephyr Starter Package', type='Bundle', properties={}), target=Node(id='Photography', type='Tag', properties={}), type='TAGGED_WITH', properties={}), Relationship(source=Node(id='Skyhawk Zephyr Starter Package', type='Bundle', properties={}), target=Node(id='Videography', type='Tag', properties={}), type='TAGGED_WITH', properties={})]
#
#
#   Product: SkyHawk Zephyr Propeller Guards
#   Price: $14.99
#   Weight: 20g (0.7 oz)
#   Fly with Confid === truncated ===
# [Node(id='Skyhawk Zephyr Propeller Guards', type='Product', properties={'price': '14.99', 'weight': '20g (0.7 oz)', 'features': 'Increased Durability: Provides an extra layer of protection for your drone.', 'embedding': '...'}), Node(id='Skyhawk Zephyr Drone', type='Product', properties={}), Node(id='Photography', type='Tag', properties={}), Node(id='Videography', type='Tag', properties={})]
# [Relationship(source=Node(id='Skyhawk Zephyr Propeller Guards', type='Product', properties={}), target=Node(id='Skyhawk Zephyr Drone', type='Product', properties={}), type='IS_ACCESSORY_OF', properties={}), Relationship(source=Node(id='Skyhawk Zephyr Propeller Guards', type='Product', properties={}), target=Node(id='Photography', type='Tag', properties={}), type='TAGGED_WITH', properties={}), Relationship(source=Node(id='Skyhawk Zephyr Propeller Guards', type='Product', properties={}), target=Node(id='Videography', type='Tag', properties={}), type='TAGGED_WITH', properties={})]
#
#
#   Product: SkyHawk Zephyr Extended Battery
#   Price: $29.99
#   Weight: 70g (2.5 oz)
#   Fly Longer, Exp === truncated ===
# [Node(id='Skyhawk Zephyr Extended Battery', type='Product', properties={'price': '$29.99', 'weight': '70g (2.5 oz)', 'features': 'Increased Capacity: Enjoy up to 25 minutes of flight time on a single charge, a 67% increase over the standard battery.\nEasy Installation: Seamlessly swap out with the original battery in seconds.\nSafe and Reliable: Built to the same high-quality standards as the SkyHawk Zephyr drone.', 'embedding': '...'}), Node(id='Skyhawk Zephyr Drone', type='Product', properties={}), Node(id='Photography', type='Tag', properties={}), Node(id='Videography', type='Tag', properties={})]
# [Relationship(source=Node(id='Skyhawk Zephyr Extended Battery', type='Product', properties={}), target=Node(id='Skyhawk Zephyr Drone', type='Product', properties={}), type='IS_ACCESSORY_OF', properties={}), Relationship(source=Node(id='Skyhawk Zephyr Extended Battery', type='Product', properties={}), target=Node(id='Photography', type='Tag', properties={}), type='TAGGED_WITH', properties={}), Relationship(source=Node(id='Skyhawk Zephyr Extended Battery', type='Product', properties={}), target=Node(id='Videography', type='Tag', properties={}), type='TAGGED_WITH', properties={})]
#
#
#   Product: SkyHawk Zephyr 2.0 - Reach New Heights
#   Price: $199.99
#   Weight: 250g (8.8 oz)
#   Soar t === truncated ===
# [Node(id='Skyhawk Zephyr 2.0', type='Product', properties={'price': '$199.99', 'weight': '250g (8.8 oz)', 'features': 'Streamlined Design: A sleek and aerodynamic design for improved flight performance.', 'embedding': '...'}), Node(id='Drone', type='Category', properties={}), Node(id='Home', type='Segment', properties={}), Node(id='Photography', type='Tag', properties={}), Node(id='Videography', type='Tag', properties={}), Node(id='Skyhawk Zephyr Drone', type='Product', properties={})]
# [Relationship(source=Node(id='Skyhawk Zephyr 2.0', type='Product', properties={}), target=Node(id='Drone', type='Category', properties={}), type='IN_CATEGORY', properties={}), Relationship(source=Node(id='Skyhawk Zephyr 2.0', type='Product', properties={}), target=Node(id='Home', type='Segment', properties={}), type='IN_SEGMENT', properties={}), Relationship(source=Node(id='Skyhawk Zephyr 2.0', type='Product', properties={}), target=Node(id='Photography', type='Tag', properties={}), type='TAGGED_WITH', properties={}), Relationship(source=Node(id='Skyhawk Zephyr 2.0', type='Product', properties={}), target=Node(id='Videography', type='Tag', properties={}), type='TAGGED_WITH', properties={}), Relationship(source=Node(id='Skyhawk Zephyr 2.0', type='Product', properties={}), target=Node(id='Skyhawk Zephyr Drone', type='Product', properties={}), type='IS_UPGRADE_OF', properties={})]
#
#
#   Product: SkyHawk Zephyr Drone
#   Price: $129.99
#   Weight: 220g (7.8 oz)
#   The SkyHawk Zephyr is th === truncated ===
# [Node(id='Skyhawk Zephyr Drone', type='Product', properties={'price': '129.99', 'weight': '220g (7.8 oz)', 'features': 'Worry-Free Flying: Free Fly mode lets you fly without directional concerns.', 'embedding': '...'}), Node(id='Drone', type='Category', properties={}), Node(id='Home', type='Segment', properties={}), Node(id='Photography', type='Tag', properties={}), Node(id='Videography', type='Tag', properties={})]
# [Relationship(source=Node(id='Skyhawk Zephyr Drone', type='Product', properties={}), target=Node(id='Drone', type='Category', properties={}), type='IN_CATEGORY', properties={}), Relationship(source=Node(id='Skyhawk Zephyr Drone', type='Product', properties={}), target=Node(id='Home', type='Segment', properties={}), type='IN_SEGMENT', properties={}), Relationship(source=Node(id='Skyhawk Zephyr Drone', type='Product', properties={}), target=Node(id='Photography', type='Tag', properties={}), type='TAGGED_WITH', properties={}), Relationship(source=Node(id='Skyhawk Zephyr Drone', type='Product', properties={}), target=Node(id='Videography', type='Tag', properties={}), type='TAGGED_WITH', properties={})]
#
#
# Office Bundle
#
# Price: $1600
#
# Manufacturer: Aura Systems
#
# Description: Enhance your productivity wit === truncated ===
# [Node(id='Office Bundle', type='Bundle', properties={'price': '1600'}), Node(id='Aurabook Air', type='Product', properties={'name': 'AuraBook Air'}), Node(id='Lumix Keyboard', type='Product', properties={'name': 'Lumix Keyboard'}), Node(id='Privacyguard Standard', type='Product', properties={'name': 'PrivacyGuard Standard'}), Node(id='Bundles', type='Category', properties={}), Node(id='Home', type='Segment', properties={}), Node(id='Office', type='Segment', properties={}), Node(id='Computer', type='Tag', properties={})]
# [Relationship(source=Node(id='Office Bundle', type='Bundle', properties={}), target=Node(id='Aurabook Air', type='Product', properties={}), type='IN_BUNDLE', properties={}), Relationship(source=Node(id='Office Bundle', type='Bundle', properties={}), target=Node(id='Lumix Keyboard', type='Product', properties={}), type='IN_BUNDLE', properties={}), Relationship(source=Node(id='Office Bundle', type='Bundle', properties={}), target=Node(id='Privacyguard Standard', type='Product', properties={}), type='IN_BUNDLE', properties={}), Relationship(source=Node(id='Office Bundle', type='Bundle', properties={}), target=Node(id='Bundles', type='Category', properties={}), type='IN_CATEGORY', properties={}), Relationship(source=Node(id='Office Bundle', type='Bundle', properties={}), target=Node(id='Home', type='Segment', properties={}), type='IN_SEGMENT', properties={}), Relationship(source=Node(id='Office Bundle', type='Bundle', properties={}), target=Node(id='Office', type='Segment', properties={}), type='IN_SEGMENT', properties={}), Relationship(source=Node(id='Office Bundle', type='Bundle', properties={}), target=Node(id='Computer', type='Tag', properties={}), type='TAGGED_WITH', properties={})]
#
#
# **Product Summary: AuraBook Air**
#
# Stay productive on the move with the AuraBook Air, a lightweight === truncated ===
# [Node(id='Aurabook Air', type='Product', properties={'price': '999.00', 'features': 'Sleek, modern design', 'embedding': '...'}), Node(id='Laptops', type='Category', properties={}), Node(id='Home', type='Segment', properties={}), Node(id='Office', type='Segment', properties={}), Node(id='Computer', type='Tag', properties={}), Node(id='Privacyguard Standard', type='Product', properties={}), Node(id='Lumix Keyboard', type='Product', properties={})]
# [Relationship(source=Node(id='Aurabook Air', type='Product', properties={}), target=Node(id='Laptops', type='Category', properties={}), type='IN_CATEGORY', properties={}), Relationship(source=Node(id='Aurabook Air', type='Product', properties={}), target=Node(id='Home', type='Segment', properties={}), type='IN_SEGMENT', properties={}), Relationship(source=Node(id='Aurabook Air', type='Product', properties={}), target=Node(id='Office', type='Segment', properties={}), type='IN_SEGMENT', properties={}), Relationship(source=Node(id='Aurabook Air', type='Product', properties={}), target=Node(id='Computer', type='Tag', properties={}), type='TAGGED_WITH', properties={}), Relationship(source=Node(id='Privacyguard Standard', type='Product', properties={}), target=Node(id='Aurabook Air', type='Product', properties={}), type='IS_ACCESSORY_OF', properties={}), Relationship(source=Node(id='Lumix Keyboard', type='Product', properties={}), target=Node(id='Aurabook Air', type='Product', properties={}), type='IS_ACCESSORY_OF', properties={})]
#
#
# **Product Summary: AuraView 32 Pro**
#
# Immerse yourself in stunning visuals with the AuraView 32 Pro === truncated ===
# [Node(id='Auraview 32 Pro', type='Product', properties={'price': '599.99', 'features': 'Built-in Speakers', 'embedding': '...'}), Node(id='Monitors', type='Category', properties={}), Node(id='Home', type='Segment', properties={}), Node(id='Office', type='Segment', properties={}), Node(id='Computer', type='Tag', properties={}), Node(id='Ergoflex Pro', type='Product', properties={})]
# [Relationship(source=Node(id='Auraview 32 Pro', type='Product', properties={}), target=Node(id='Monitors', type='Category', properties={}), type='IN_CATEGORY', properties={}), Relationship(source=Node(id='Auraview 32 Pro', type='Product', properties={}), target=Node(id='Home', type='Segment', properties={}), type='IN_SEGMENT', properties={}), Relationship(source=Node(id='Auraview 32 Pro', type='Product', properties={}), target=Node(id='Office', type='Segment', properties={}), type='IN_SEGMENT', properties={}), Relationship(source=Node(id='Auraview 32 Pro', type='Product', properties={}), target=Node(id='Computer', type='Tag', properties={}), type='TAGGED_WITH', properties={}), Relationship(source=Node(id='Ergoflex Pro', type='Product', properties={}), target=Node(id='Auraview 32 Pro', type='Product', properties={}), type='IS_ACCESSORY_OF', properties={})]
#
#
# Product Summary: Quantum Charger
#
# Stay powered up and ready to go with the Quantum Charger, designe === truncated ===
# [Node(id='Quantum Charger', type='Product', properties={'price': '69.00', 'weight': '0.25 lbs', 'features': 'LED Indicator Light', 'embedding': '...'}), Node(id='Aurabook X500', type='Product', properties={}), Node(id='Accessories', type='Category', properties={}), Node(id='Home', type='Segment', properties={}), Node(id='Office', type='Segment', properties={}), Node(id='Computer', type='Tag', properties={})]
# [Relationship(source=Node(id='Quantum Charger', type='Product', properties={}), target=Node(id='Aurabook X500', type='Product', properties={}), type='IS_ACCESSORY_OF', properties={}), Relationship(source=Node(id='Quantum Charger', type='Product', properties={}), target=Node(id='Accessories', type='Category', properties={}), type='IN_CATEGORY', properties={}), Relationship(source=Node(id='Quantum Charger', type='Product', properties={}), target=Node(id='Home', type='Segment', properties={}), type='IN_SEGMENT', properties={}), Relationship(source=Node(id='Quantum Charger', type='Product', properties={}), target=Node(id='Office', type='Segment', properties={}), type='IN_SEGMENT', properties={}), Relationship(source=Node(id='Quantum Charger', type='Product', properties={}), target=Node(id='Computer', type='Tag', properties={}), type='TAGGED_WITH', properties={})]
#
#
# Dual Monitor Productivity Bundle
#
# Price: $849.99
#
# Manufacturer: Aura Displays
#
# Description: Superch === truncated ===
# [Node(id='Dual Monitor Productivity Bundle', type='Bundle', properties={'price': '849.99'}), Node(id='Aura Displays', type='Product', properties={'name': 'Aura Displays'}), Node(id='Auraview 32', type='Product', properties={}), Node(id='Bundles', type='Category', properties={}), Node(id='Home', type='Segment', properties={}), Node(id='Office', type='Segment', properties={}), Node(id='Computer', type='Tag', properties={})]
# [Relationship(source=Node(id='Dual Monitor Productivity Bundle', type='Bundle', properties={}), target=Node(id='Auraview 32', type='Product', properties={}), type='IN_BUNDLE', properties={}), Relationship(source=Node(id='Dual Monitor Productivity Bundle', type='Bundle', properties={}), target=Node(id='Bundles', type='Category', properties={}), type='IN_CATEGORY', properties={}), Relationship(source=Node(id='Dual Monitor Productivity Bundle', type='Bundle', properties={}), target=Node(id='Home', type='Segment', properties={}), type='IN_SEGMENT', properties={}), Relationship(source=Node(id='Dual Monitor Productivity Bundle', type='Bundle', properties={}), target=Node(id='Office', type='Segment', properties={}), type='IN_SEGMENT', properties={}), Relationship(source=Node(id='Dual Monitor Productivity Bundle', type='Bundle', properties={}), target=Node(id='Computer', type='Tag', properties={}), type='TAGGED_WITH', properties={})]
#
#
# Product Summary: SecureView Privacy Screen
#
# Price: $79.00
#
# Manufacturer: AuraTech (Designed for Aur === truncated ===
# [Node(id='Secureview Privacy Screen', type='Product', properties={'price': '79.00'}), Node(id='Aurabook X500', type='Product', properties={}), Node(id='Aurabook Air', type='Product', properties={}), Node(id='Laptop Privacy Screen', type='Category', properties={}), Node(id='Home', type='Segment', properties={}), Node(id='Office', type='Segment', properties={}), Node(id='Computer', type='Tag', properties={})]
# [Relationship(source=Node(id='Secureview Privacy Screen', type='Product', properties={}), target=Node(id='Laptop Privacy Screen', type='Category', properties={}), type='IN_CATEGORY', properties={}), Relationship(source=Node(id='Secureview Privacy Screen', type='Product', properties={}), target=Node(id='Home', type='Segment', properties={}), type='IN_SEGMENT', properties={}), Relationship(source=Node(id='Secureview Privacy Screen', type='Product', properties={}), target=Node(id='Office', type='Segment', properties={}), type='IN_SEGMENT', properties={}), Relationship(source=Node(id='Secureview Privacy Screen', type='Product', properties={}), target=Node(id='Computer', type='Tag', properties={}), type='TAGGED_WITH', properties={}), Relationship(source=Node(id='Secureview Privacy Screen', type='Product', properties={}), target=Node(id='Aurabook X500', type='Product', properties={}), type='IS_ACCESSORY_OF', properties={}), Relationship(source=Node(id='Secureview Privacy Screen', type='Product', properties={}), target=Node(id='Aurabook Air', type='Product', properties={}), type='IS_ACCESSORY_OF', properties={})]
#
#
# Product Summary:
#
# Product Name: Blue Light Filter Screen
#
# Price: $39.99
#
# Description: Combat eye st === truncated ===
# [Node(id='Blue Light Filter Screen', type='Product', properties={'price': '39.99', 'features': 'Lightweight and Durable', 'weight': '1.2 lbs', 'embedding': '...'}), Node(id='Accessories', type='Category', properties={}), Node(id='Home', type='Segment', properties={}), Node(id='Office', type='Segment', properties={}), Node(id='Computer', type='Tag', properties={}), Node(id='Auraview 32', type='Product', properties={}), Node(id='Auraview 32 Pro', type='Product', properties={})]
# ...
# [Node(id='Chromajet Pro Xl Studio Bundle', type='Bundle', properties={'price': '928.00'}), Node(id='Chromajet Pro Xl Printer', type='Product', properties={}), Node(id='Chromashield Laminator', type='Product', properties={}), Node(id='Printing', type='Tag', properties={})]
# [Relationship(source=Node(id='Chromajet Pro Xl Studio Bundle', type='Bundle', properties={}), target=Node(id='Chromajet Pro Xl Printer', type='Product', properties={}), type='IN_BUNDLE', properties={}), Relationship(source=Node(id='Chromajet Pro Xl Studio Bundle', type='Bundle', properties={}), target=Node(id='Chromashield Laminator', type='Product', properties={}), type='IN_BUNDLE', properties={}), Relationship(source=Node(id='Chromajet Pro Xl Studio Bundle', type='Bundle', properties={}), target=Node(id='Printing', type='Tag', properties={}), type='TAGGED_WITH', properties={})]
#
#
# ChromaPaper Pro Pack
#
# Price: $49.99
#
# Description: Achieve exceptional print quality with the Chroma === truncated ===
# [Node(id='Chromapaper Pro Pack', type='Product', properties={'price': '49.99'}), Node(id='Chromajet Pro Xl Printer', type='Product', properties={}), Node(id='Printing', type='Tag', properties={})]
# [Relationship(source=Node(id='Chromapaper Pro Pack', type='Product', properties={}), target=Node(id='Chromajet Pro Xl Printer', type='Product', properties={}), type='IS_ACCESSORY_OF', properties={}), Relationship(source=Node(id='Chromapaper Pro Pack', type='Product', properties={}), target=Node(id='Printing', type='Tag', properties={}), type='TAGGED_WITH', properties={})]
#
#
#  ChromaJet Pro XL
#
# Price: $799.00
#
# Manufacturer: ChromaTech
#
# Description: Unlock professional-grade === truncated ===
# [Node(id='Chromajet Pro Xl', type='Product', properties={'price': '799.00', 'name': 'ChromaJet Pro XL', 'weight': '18 lbs'}), Node(id='Chromatech', type='Category', properties={'name': 'Printer'}), Node(id='Home', type='Segment', properties={'name': 'Home'}), Node(id='Office', type='Segment', properties={'name': 'Office'}), Node(id='Printing', type='Tag', properties={'name': 'Printing'}), Node(id='Chromajet Pro', type='Product', properties={}), Node(id='Chromashield Laminator', type='Product', properties={}), Node(id='Chromaclean Kit', type='Product', properties={}), Node(id='Chromapaper Pro Pack', type='Product', properties={})]
# [Relationship(source=Node(id='Chromajet Pro Xl', type='Product', properties={}), target=Node(id='Chromatech', type='Category', properties={}), type='IN_CATEGORY', properties={}), Relationship(source=Node(id='Chromajet Pro Xl', type='Product', properties={}), target=Node(id='Home', type='Segment', properties={}), type='IN_SEGMENT', properties={}), Relationship(source=Node(id='Chromajet Pro Xl', type='Product', properties={}), target=Node(id='Office', type='Segment', properties={}), type='IN_SEGMENT', properties={}), Relationship(source=Node(id='Chromajet Pro Xl', type='Product', properties={}), target=Node(id='Printing', type='Tag', properties={}), type='TAGGED_WITH', properties={}), Relationship(source=Node(id='Chromajet Pro Xl', type='Product', properties={}), target=Node(id='Chromajet Pro', type='Product', properties={}), type='IS_UPGRADE_OF', properties={}), Relationship(source=Node(id='Chromashield Laminator', type='Product', properties={}), target=Node(id='Chromajet Pro Xl', type='Product', properties={}), type='IS_ACCESSORY_OF', properties={}), Relationship(source=Node(id='Chromaclean Kit', type='Product', properties={}), target=Node(id='Chromajet Pro Xl', type='Product', properties={}), type='IS_ACCESSORY_OF', properties={}), Relationship(source=Node(id='Chromapaper Pro Pack', type='Product', properties={}), target=Node(id='Chromajet Pro Xl', type='Product', properties={}), type='IS_ACCESSORY_OF', properties={})]
#
#
#  ChromaShield Laminator
#
# Price: $149.00
#
# Protect your valuable prints from fading, scratches, and m === truncated ===
# [Node(id='Chromashield Laminator', type='Product', properties={'price': '149.00', 'features': 'User-Friendly Controls', 'weight': '5 lbs', 'embedding': '...'}), Node(id='Chromajet Pro', type='Product', properties={}), Node(id='Chromajet Pro Xl Printers', type='Product', properties={}), Node(id='Printing', type='Tag', properties={})]
# [Relationship(source=Node(id='Chromashield Laminator', type='Product', properties={}), target=Node(id='Chromajet Pro', type='Product', properties={}), type='IS_ACCESSORY_OF', properties={}), Relationship(source=Node(id='Chromashield Laminator', type='Product', properties={}), target=Node(id='Chromajet Pro Xl Printers', type='Product', properties={}), type='IS_ACCESSORY_OF', properties={}), Relationship(source=Node(id='Chromashield Laminator', type='Product', properties={}), target=Node(id='Printing', type='Tag', properties={}), type='TAGGED_WITH', properties={})]
#
#
#  ChromaPaper Pro Pack
#
# Price: $49.99
#
# Description: Achieve exceptional print quality with the Chrom === truncated ===
# [Node(id='Chromapaper Pro Pack', type='Product', properties={'price': '49.99'}), Node(id='Chromajet Pro Xl Printer', type='Product', properties={}), Node(id='Printing', type='Tag', properties={})]
# [Relationship(source=Node(id='Chromapaper Pro Pack', type='Product', properties={}), target=Node(id='Chromajet Pro Xl Printer', type='Product', properties={}), type='IS_ACCESSORY_OF', properties={}), Relationship(source=Node(id='Chromapaper Pro Pack', type='Product', properties={}), target=Node(id='Printing', type='Tag', properties={}), type='TAGGED_WITH', properties={})]
#
#
# ChromaJet Pro
#
# Price: $499.00
#
# Manufacturer: Pixel Perfect Technologies
#
# Description: Experience vi === truncated ===
# [Node(id='Chromajet Pro', type='Product', properties={'price': '499.00'}), Node(id='Printer', type='Category', properties={}), Node(id='Home', type='Segment', properties={}), Node(id='Office', type='Segment', properties={}), Node(id='Printing', type='Tag', properties={}), Node(id='Chromashield Laminator', type='Product', properties={}), Node(id='Chromaclean Kit', type='Product', properties={})]
# [Relationship(source=Node(id='Chromajet Pro', type='Product', properties={}), target=Node(id='Printer', type='Category', properties={}), type='IN_CATEGORY', properties={}), Relationship(source=Node(id='Chromajet Pro', type='Product', properties={}), target=Node(id='Home', type='Segment', properties={}), type='IN_SEGMENT', properties={}), Relationship(source=Node(id='Chromajet Pro', type='Product', properties={}), target=Node(id='Office', type='Segment', properties={}), type='IN_SEGMENT', properties={}), Relationship(source=Node(id='Chromajet Pro', type='Product', properties={}), target=Node(id='Printing', type='Tag', properties={}), type='TAGGED_WITH', properties={}), Relationship(source=Node(id='Chromashield Laminator', type='Product', properties={}), target=Node(id='Chromajet Pro', type='Product', properties={}), type='IS_ACCESSORY_OF', properties={}), Relationship(source=Node(id='Chromaclean Kit', type='Product', properties={}), target=Node(id='Chromajet Pro', type='Product', properties={}), type='IS_ACCESSORY_OF', properties={})]
#
#
#   Bundle: SnapShot Voyager Creative Studio Kit
#   Price: $349.99
#   Everything you need to expand you === truncated ===
# [Node(id='Snapshot Voyager Creative Studio Kit', type='Bundle', properties={'price': '349.99'}), Node(id='Snapshot Voyager Camera 3.0', type='Product', properties={}), Node(id='32Gb Sd Memory Card', type='Product', properties={}), Node(id='Mini Tripod', type='Product', properties={}), Node(id='Uv Protection Filter', type='Product', properties={}), Node(id='Polarizing Filter', type='Product', properties={}), Node(id='Camera Bag', type='Product', properties={}), Node(id='Rechargeable Battery', type='Product', properties={}), Node(id='Usb Charging Cable', type='Product', properties={}), Node(id='Lens Cleaning Kit', type='Product', properties={}), Node(id='User Manual', type='Product', properties={}), Node(id='Photography', type='Tag', properties={})]
# [Relationship(source=Node(id='Snapshot Voyager Creative Studio Kit', type='Bundle', properties={}), target=Node(id='Snapshot Voyager Camera 3.0', type='Product', properties={}), type='IN_BUNDLE', properties={}), Relationship(source=Node(id='Snapshot Voyager Creative Studio Kit', type='Bundle', properties={}), target=Node(id='32Gb Sd Memory Card', type='Product', properties={}), type='IN_BUNDLE', properties={}), Relationship(source=Node(id='Snapshot Voyager Creative Studio Kit', type='Bundle', properties={}), target=Node(id='Mini Tripod', type='Product', properties={}), type='IN_BUNDLE', properties={}), Relationship(source=Node(id='Snapshot Voyager Creative Studio Kit', type='Bundle', properties={}), target=Node(id='Uv Protection Filter', type='Product', properties={}), type='IN_BUNDLE', properties={}), Relationship(source=Node(id='Snapshot Voyager Creative Studio Kit', type='Bundle', properties={}), target=Node(id='Polarizing Filter', type='Product', properties={}), type='IN_BUNDLE', properties={}), Relationship(source=Node(id='Snapshot Voyager Creative Studio Kit', type='Bundle', properties={}), target=Node(id='Camera Bag', type='Product', properties={}), type='IN_BUNDLE', properties={}), Relationship(source=Node(id='Snapshot Voyager Creative Studio Kit', type='Bundle', properties={}), target=Node(id='Rechargeable Battery', type='Product', properties={}), type='IN_BUNDLE', properties={}), Relationship(source=Node(id='Snapshot Voyager Creative Studio Kit', type='Bundle', properties={}), target=Node(id='Usb Charging Cable', type='Product', properties={}), type='IN_BUNDLE', properties={}), Relationship(source=Node(id='Snapshot Voyager Creative Studio Kit', type='Bundle', properties={}), target=Node(id='Lens Cleaning Kit', type='Product', properties={}), type='IN_BUNDLE', properties={}), Relationship(source=Node(id='Snapshot Voyager Creative Studio Kit', type='Bundle', properties={}), target=Node(id='User Manual', type='Product', properties={}), type='IN_BUNDLE', properties={}), Relationship(source=Node(id='Snapshot Voyager Creative Studio Kit', type='Bundle', properties={}), target=Node(id='Photography', type='Tag', properties={}), type='TAGGED_WITH', properties={})]
#
#
#   Bundle: SnapShot Voyager Photography Essentials
#   Price: $299.99
#   Everything you need to start c === truncated ===
# [Node(id='Snapshot Voyager Photography Essentials', type='Bundle', properties={'price': '299.99'}), Node(id='Snapshot Voyager Camera 3.0', type='Product', properties={}), Node(id='16Gb Sd Memory Card', type='Product', properties={}), Node(id='Camera Carrying Case', type='Product', properties={}), Node(id='Rechargeable Battery', type='Product', properties={}), Node(id='Usb Charging Cable', type='Product', properties={}), Node(id='Lens Cleaning Cloth', type='Product', properties={}), Node(id='User Manual', type='Product', properties={}), Node(id='Photography', type='Tag', properties={})]
# [Relationship(source=Node(id='Snapshot Voyager Photography Essentials', type='Bundle', properties={}), target=Node(id='Snapshot Voyager Camera 3.0', type='Product', properties={}), type='IN_BUNDLE', properties={}), Relationship(source=Node(id='Snapshot Voyager Photography Essentials', type='Bundle', properties={}), target=Node(id='16Gb Sd Memory Card', type='Product', properties={}), type='IN_BUNDLE', properties={}), Relationship(source=Node(id='Snapshot Voyager Photography Essentials', type='Bundle', properties={}), target=Node(id='Camera Carrying Case', type='Product', properties={}), type='IN_BUNDLE', properties={}), Relationship(source=Node(id='Snapshot Voyager Photography Essentials', type='Bundle', properties={}), target=Node(id='Rechargeable Battery', type='Product', properties={}), type='IN_BUNDLE', properties={}), Relationship(source=Node(id='Snapshot Voyager Photography Essentials', type='Bundle', properties={}), target=Node(id='Usb Charging Cable', type='Product', properties={}), type='IN_BUNDLE', properties={}), Relationship(source=Node(id='Snapshot Voyager Photography Essentials', type='Bundle', properties={}), target=Node(id='Lens Cleaning Cloth', type='Product', properties={}), type='IN_BUNDLE', properties={}), Relationship(source=Node(id='Snapshot Voyager Photography Essentials', type='Bundle', properties={}), target=Node(id='User Manual', type='Product', properties={}), type='IN_BUNDLE', properties={}), Relationship(source=Node(id='Snapshot Voyager Photography Essentials', type='Bundle', properties={}), target=Node(id='Photography', type='Tag', properties={}), type='TAGGED_WITH', properties={})]
#
#
#   Product: SnapShot Voyager Remote Shutter Release
#   Price: $24.99
#   Weight: 40g (1.4 oz)
#   Capture === truncated ===
# [Node(id='Snapshot Voyager Remote Shutter Release', type='Product', properties={'price': '24.99', 'weight': '40g (1.4 oz)', 'features': "Easy Connection: Plugs directly into the camera's remote port for quick and simple setup.", 'embedding': '...'}), Node(id='Snapshot Voyager Camera 3.0', type='Product', properties={}), Node(id='Photography', type='Tag', properties={})]
# [Relationship(source=Node(id='Snapshot Voyager Remote Shutter Release', type='Product', properties={}), target=Node(id='Snapshot Voyager Camera 3.0', type='Product', properties={}), type='IS_ACCESSORY_OF', properties={}), Relationship(source=Node(id='Snapshot Voyager Remote Shutter Release', type='Product', properties={}), target=Node(id='Photography', type='Tag', properties={}), type='TAGGED_WITH', properties={})]
#
#
#   Product: SnapShot Voyager Lens Hood
#   Price: $19.99
#   Weight: 30g (1.1 oz)
#   Capture Images with  === truncated ===
# [Node(id='Snapshot Voyager Lens Hood', type='Product', properties={'price': '19.99', 'weight': '30g (1.1 oz)', 'features': 'Easy Attachment: Screws securely onto the lens for a snug and reliable fit.', 'embedding': '...'}), Node(id='Snapshot Voyager Camera 3.0', type='Product', properties={}), Node(id='Photography', type='Tag', properties={})]
# [Relationship(source=Node(id='Snapshot Voyager Lens Hood', type='Product', properties={}), target=Node(id='Snapshot Voyager Camera 3.0', type='Product', properties={}), type='IS_ACCESSORY_OF', properties={}), Relationship(source=Node(id='Snapshot Voyager Lens Hood', type='Product', properties={}), target=Node(id='Photography', type='Tag', properties={}), type='TAGGED_WITH', properties={})]
#
#
#   Limited-Time Offer: SnapShot Voyager Remote Shutter Release
#   Capture Blur-Free Images & Save!
#    === truncated ===
# [Node(id='Snapshot Voyager Remote Shutter Release', type='Product', properties={'price': '16.99'}), Node(id='Deal', type='Deal', properties={'deal_end_date': '2025-02-28'}), Node(id='Photography', type='Tag', properties={})]
# [Relationship(source=Node(id='Snapshot Voyager Remote Shutter Release', type='Product', properties={}), target=Node(id='Deal', type='Deal', properties={}), type='HAS_DEAL', properties={}), Relationship(source=Node(id='Snapshot Voyager Remote Shutter Release', type='Product', properties={}), target=Node(id='Photography', type='Tag', properties={}), type='TAGGED_WITH', properties={})]
#
#
#   Product: SnapShot Voyager Camera 3.0
#   Price: $249.99
#   Weight: 350g (12.3 oz)
#   Capture Your Wor === truncated ===
# [Node(id='Snapshot Voyager Camera 3.0', type='Product', properties={'price': '249.99', 'weight': '350g (12.3 oz)', 'features': 'Long Battery Life', 'embedding': '...'}), Node(id='Camera', type='Category', properties={}), Node(id='Home', type='Segment', properties={}), Node(id='Photography', type='Tag', properties={})]
# [Relationship(source=Node(id='Snapshot Voyager Camera 3.0', type='Product', properties={}), target=Node(id='Camera', type='Category', properties={}), type='IN_CATEGORY', properties={}), Relationship(source=Node(id='Snapshot Voyager Camera 3.0', type='Product', properties={}), target=Node(id='Home', type='Segment', properties={}), type='IN_SEGMENT', properties={}), Relationship(source=Node(id='Snapshot Voyager Camera 3.0', type='Product', properties={}), target=Node(id='Photography', type='Tag', properties={}), type='TAGGED_WITH', properties={})]

# %% [markdown]
# ### Post process extracted nodes and edges
#
# Apply your domain knowledge to clean up and make desired fixes to the generated graph in the earlier step.

# %%
# set of all valid products
products = set()

def prune_invalid_products():
    for graph_document in graph_documents:
        nodes_to_remove = []
        relationships_to_remove = []
        for node in graph_document.nodes:
            if node.type == "Product" and "features" not in node.properties:
                nodes_to_remove.append(node)
            else:
                products.add(node.id)
        for node in nodes_to_remove:
            graph_document.nodes.remove(node)


def prune_invalid_segments(valid_segments):
    for graph_document in graph_documents:
        nodes_to_remove = []
        for node in graph_document.nodes:
            if node.type == "Segment" and node.id not in valid_segments:
                nodes_to_remove.append(node)
        for node in nodes_to_remove:
            graph_document.nodes.remove(node)


def fix_directions(relation_name, wrong_source_type):
    for graph_document in graph_documents:
        for relationship in graph_document.relationships:
            if relationship.type == relation_name:
                if relationship.source.type == wrong_source_type:
                    source = relationship.source
                    target = relationship.target
                    relationship.source = target
                    relationship.target = source


def is_not_a_listed_product(node):
    if node.type == "Product" and node.id not in products:
        return True
    return False


def prune_dangling_relationships():
    # now remove all dangling relationships
    for graph_document in graph_documents:
        relationships_to_remove = []
        for relationship in graph_document.relationships:
            if is_not_a_listed_product(relationship.source) or is_not_a_listed_product(
                relationship.target
            ):
                relationships_to_remove.append(relationship)
        for relationship in relationships_to_remove:
            graph_document.relationships.remove(relationship)


def prune_unwanted_relationships(relation_name, source, target):
    node_types = set([source, target])
    for graph_document in graph_documents:
        relationships_to_remove = []
        for relationship in graph_document.relationships:
            if (
                relationship.type == relation_name
                and set([relationship.source.type, relationship.target.type])
                == node_types
            ):
                relationships_to_remove.append(relationship)
        for relationship in relationships_to_remove:
            graph_document.relationships.remove(relationship)


prune_invalid_products()
prune_invalid_segments(set(["Home", "Office", "Fitness"]))
prune_unwanted_relationships("IN_CATEGORY", "Bundle", "Category")
prune_unwanted_relationships("IN_CATEGORY", "Deal", "Category")
prune_unwanted_relationships("IN_SEGMENT", "Bundle", "Segment")
prune_unwanted_relationships("IN_SEGMENT", "Deal", "Segment")
prune_dangling_relationships()
fix_directions("HAS_DEAL", "Deal")
fix_directions("IN_BUNDLE", "Bundle")

print_graph(graph_documents)
# Out:
#  **QuantumLeap Flash Friday Deal - Unleash Blazing Fast Storage!**
#
# **Price:** $39.99
#
# **Manufactur === truncated ===
# [Node(id='Quantumleap Flash Friday Deal', type='Deal', properties={'deal_end_date': '2024-03-01'}), Node(id='Storage', type='Tag', properties={}), Node(id='Data', type='Tag', properties={})]
# []
#
#
#  DataSafe Vault
#
# Price: $39.99
#
# Manufacturer: SecureTech Solutions
#
# Description: Keep your sensitiv === truncated ===
# [Node(id='Storage', type='Tag', properties={}), Node(id='Data', type='Tag', properties={})]
# []
#
#
#  QuantumLeap Ultimate Kit
#
# Price: $64.99
#
# Manufacturer: QuantumLeap Technologies
#
# Description: Unle === truncated ===
# [Node(id='Quantumleap Ultimate Kit', type='Bundle', properties={'price': '64.99'}), Node(id='Quantumleap Technologies', type='Category', properties={}), Node(id='Storage', type='Tag', properties={}), Node(id='Data', type='Tag', properties={})]
# [Relationship(source=Node(id='Universal Adapter Kit', type='Product', properties={}), target=Node(id='Quantumleap Ultimate Kit', type='Bundle', properties={}), type='IN_BUNDLE', properties={}), Relationship(source=Node(id='Quantumleap Ultimate Kit', type='Bundle', properties={}), target=Node(id='Storage', type='Tag', properties={}), type='TAGGED_WITH', properties={}), Relationship(source=Node(id='Quantumleap Ultimate Kit', type='Bundle', properties={}), target=Node(id='Data', type='Tag', properties={}), type='TAGGED_WITH', properties={})]
#
#
#  Product Summary: QuantumLeap Flash
#
# Blazing-fast storage in a sleek, retractable design. The Quant === truncated ===
# [Node(id='Quantumleap Flash', type='Product', properties={'price': '49.99', 'features': 'LED Activity Indicator', 'embedding': '...'}), Node(id='Usb Flash Drive', type='Category', properties={}), Node(id='Home', type='Segment', properties={}), Node(id='Office', type='Segment', properties={}), Node(id='Storage', type='Tag', properties={}), Node(id='Data', type='Tag', properties={})]
# [Relationship(source=Node(id='Quantumleap Flash', type='Product', properties={}), target=Node(id='Usb Flash Drive', type='Category', properties={}), type='IN_CATEGORY', properties={}), Relationship(source=Node(id='Quantumleap Flash', type='Product', properties={}), target=Node(id='Home', type='Segment', properties={}), type='IN_SEGMENT', properties={}), Relationship(source=Node(id='Quantumleap Flash', type='Product', properties={}), target=Node(id='Office', type='Segment', properties={}), type='IN_SEGMENT', properties={}), Relationship(source=Node(id='Quantumleap Flash', type='Product', properties={}), target=Node(id='Storage', type='Tag', properties={}), type='TAGGED_WITH', properties={}), Relationship(source=Node(id='Quantumleap Flash', type='Product', properties={}), target=Node(id='Data', type='Tag', properties={}), type='TAGGED_WITH', properties={}), Relationship(source=Node(id='Universal Adapter Kit', type='Product', properties={}), target=Node(id='Quantumleap Flash', type='Product', properties={}), type='IS_ACCESSORY_OF', properties={})]
#
#
#  Product Summary: Secure Erase Tool
#
# Price: $9.99
#
# Description: Ensure your sensitive data is perma === truncated ===
# [Node(id='Datasafe Solutions', type='Category', properties={'name': 'DataSafe Solutions'}), Node(id='Storage', type='Tag', properties={}), Node(id='Data', type='Tag', properties={})]
# []
#
#
#  Product Summary: Universal Adapter Kit
#
# Effortlessly connect your devices with the Universal Adapt === truncated ===
# [Node(id='Universal Adapter Kit', type='Product', properties={'price': '19.99', 'weight': '0.8 oz', 'features': 'Durable Construction: Built to withstand daily use.', 'embedding': '...'}), Node(id='Storage', type='Tag', properties={}), Node(id='Data', type='Tag', properties={})]
# [Relationship(source=Node(id='Universal Adapter Kit', type='Product', properties={}), target=Node(id='Storage', type='Tag', properties={}), type='TAGGED_WITH', properties={}), Relationship(source=Node(id='Universal Adapter Kit', type='Product', properties={}), target=Node(id='Data', type='Tag', properties={}), type='TAGGED_WITH', properties={})]
#
#
#  TitanDrive X5000 Backup Bundle - Safeguard Your Data
#
# Price: $329.99
#
# Manufacturer: TitanDrive
#
# De === truncated ===
# [Node(id='Titandrive X5000 Backup Bundle', type='Bundle', properties={'price': '329.99'}), Node(id='Storage', type='Tag', properties={}), Node(id='Data', type='Tag', properties={})]
# [Relationship(source=Node(id='Titandrive X5000', type='Product', properties={}), target=Node(id='Titandrive X5000 Backup Bundle', type='Bundle', properties={}), type='IN_BUNDLE', properties={}), Relationship(source=Node(id='Titandrive X5000 Backup Bundle', type='Bundle', properties={}), target=Node(id='Storage', type='Tag', properties={}), type='TAGGED_WITH', properties={}), Relationship(source=Node(id='Titandrive X5000 Backup Bundle', type='Bundle', properties={}), target=Node(id='Data', type='Tag', properties={}), type='TAGGED_WITH', properties={})]
#
#
#  **Product Summary: TitanDrive X5000 - 5TB Ruggedized External SSD**
#
# Unleash unparalleled speed an === truncated ===
# [Node(id='Titandrive X5000', type='Product', properties={'price': '299.99', 'weight': '119 g', 'features': 'Extreme Speed, Ruggedized Design, Massive Storage, Universal Compatibility, Compact and Portable, DataSafe Vault Compatible', 'embedding': '...'}), Node(id='External Hard Drive', type='Category', properties={}), Node(id='Home', type='Segment', properties={}), Node(id='Office', type='Segment', properties={}), Node(id='Storage', type='Tag', properties={}), Node(id='Data', type='Tag', properties={})]
# [Relationship(source=Node(id='Titandrive X5000', type='Product', properties={}), target=Node(id='External Hard Drive', type='Category', properties={}), type='IN_CATEGORY', properties={}), Relationship(source=Node(id='Titandrive X5000', type='Product', properties={}), target=Node(id='Home', type='Segment', properties={}), type='IN_SEGMENT', properties={}), Relationship(source=Node(id='Titandrive X5000', type='Product', properties={}), target=Node(id='Office', type='Segment', properties={}), type='IN_SEGMENT', properties={}), Relationship(source=Node(id='Titandrive X5000', type='Product', properties={}), target=Node(id='Storage', type='Tag', properties={}), type='TAGGED_WITH', properties={}), Relationship(source=Node(id='Titandrive X5000', type='Product', properties={}), target=Node(id='Data', type='Tag', properties={}), type='TAGGED_WITH', properties={})]
#
#
# Product Summary: Quantum Shield Screen Protector
#
# Protect your Aura X5 or Aura X5 Pro with the Quan === truncated ===
# [Node(id='Quantum Shield Screen Protector', type='Product', properties={'price': '19', 'features': 'Easy to clean', 'embedding': '...'}), Node(id='Screen Guards', type='Category', properties={}), Node(id='Home', type='Segment', properties={}), Node(id='Phone', type='Tag', properties={})]
# [Relationship(source=Node(id='Quantum Shield Screen Protector', type='Product', properties={}), target=Node(id='Screen Guards', type='Category', properties={}), type='IN_CATEGORY', properties={}), Relationship(source=Node(id='Quantum Shield Screen Protector', type='Product', properties={}), target=Node(id='Home', type='Segment', properties={}), type='IN_SEGMENT', properties={}), Relationship(source=Node(id='Quantum Shield Screen Protector', type='Product', properties={}), target=Node(id='Phone', type='Tag', properties={}), type='TAGGED_WITH', properties={})]
#
#
# Product Summary: Aura X5 Pro - Capture Brilliance, Last Longer
#
# Price: $1299.00
#
# Manufacturer: Aura === truncated ===
# [Node(id='Mobile Phones', type='Category', properties={}), Node(id='Home', type='Segment', properties={}), Node(id='Phone', type='Tag', properties={})]
# []
#
#
# Product Summary: Sonaris Pro Charging Stand
#
# Price: $29.00
#
# Manufacturer: Sonaris Audio
#
# Descriptio === truncated ===
# [Node(id='Accessories', type='Category', properties={}), Node(id='Home', type='Segment', properties={}), Node(id='Phone', type='Tag', properties={})]
# []
#
#
# Product Summary: Sonaris Pro Noise-Canceling Headphones
#
# Immerse yourself in pristine audio with th === truncated ===
# [Node(id='Sonaris Pro Noise-Canceling Headphones', type='Product', properties={'price': '249.00', 'features': 'Intuitive Controls', 'weight': '0.6 lbs', 'embedding': '...'}), Node(id='Headphones', type='Category', properties={}), Node(id='Home', type='Segment', properties={}), Node(id='Phone', type='Tag', properties={})]
# [Relationship(source=Node(id='Sonaris Pro Noise-Canceling Headphones', type='Product', properties={}), target=Node(id='Headphones', type='Category', properties={}), type='IN_CATEGORY', properties={}), Relationship(source=Node(id='Sonaris Pro Noise-Canceling Headphones', type='Product', properties={}), target=Node(id='Home', type='Segment', properties={}), type='IN_SEGMENT', properties={}), Relationship(source=Node(id='Sonaris Pro Noise-Canceling Headphones', type='Product', properties={}), target=Node(id='Phone', type='Tag', properties={}), type='TAGGED_WITH', properties={})]
#
#
#  Sonaris Max: Over-Ear Headphones - Experience Superior Sound
#
# Price: $349.00
#
# Manufacturer: Sonari === truncated ===
# [Node(id='Sonaris Max', type='Product', properties={'price': '349.00', 'features': 'Foldable design', 'weight': '9.9 ounces', 'embedding': '...'}), Node(id='Headphones', type='Category', properties={}), Node(id='Home', type='Segment', properties={}), Node(id='Phone', type='Tag', properties={})]
# [Relationship(source=Node(id='Sonaris Max', type='Product', properties={}), target=Node(id='Headphones', type='Category', properties={}), type='IN_CATEGORY', properties={}), Relationship(source=Node(id='Sonaris Max', type='Product', properties={}), target=Node(id='Home', type='Segment', properties={}), type='IN_SEGMENT', properties={}), Relationship(source=Node(id='Sonaris Max', type='Product', properties={}), target=Node(id='Phone', type='Tag', properties={}), type='TAGGED_WITH', properties={})]
#
#
# **Summer Sale! Get Aura X5 + Quantum Shield at a Discount!**
#
# **Price:** $875.00
#
# **Manufacturer:** === truncated ===
# [Node(id='Summer Sale', type='Deal', properties={'deal_end_date': '2024-07-31', 'price': '875.00'}), Node(id='Deals', type='Category', properties={}), Node(id='Home', type='Segment', properties={}), Node(id='Phone', type='Tag', properties={})]
# [Relationship(source=Node(id='Summer Sale', type='Deal', properties={}), target=Node(id='Phone', type='Tag', properties={}), type='TAGGED_WITH', properties={})]
#
#
# **Product Summary: Audio Lover's Bundle**
#
# Immerse yourself in a world of unparalleled audio fideli === truncated ===
# [Node(id="Audio Lover'S Bundle", type='Bundle', properties={'price': '550'}), Node(id='Bundles', type='Category', properties={}), Node(id='Home', type='Segment', properties={}), Node(id='Phone', type='Tag', properties={})]
# [Relationship(source=Node(id="Audio Lover'S Bundle", type='Bundle', properties={}), target=Node(id='Phone', type='Tag', properties={}), type='TAGGED_WITH', properties={})]
#
#
# Sonaris Max: Over-Ear Headphones - Experience Superior Sound
#
# Price: $349.00
#
# Manufacturer: Sonaris === truncated ===
# [Node(id='Sonaris Max', type='Product', properties={'price': '349.00', 'features': 'Foldable design for easy storage and portability', 'weight': '9.9 ounces', 'embedding': '...'}), Node(id='Headphones', type='Category', properties={}), Node(id='Home', type='Segment', properties={}), Node(id='Phone', type='Tag', properties={})]
# [Relationship(source=Node(id='Sonaris Max', type='Product', properties={}), target=Node(id='Headphones', type='Category', properties={}), type='IN_CATEGORY', properties={}), Relationship(source=Node(id='Sonaris Max', type='Product', properties={}), target=Node(id='Home', type='Segment', properties={}), type='IN_SEGMENT', properties={}), Relationship(source=Node(id='Sonaris Max', type='Product', properties={}), target=Node(id='Phone', type='Tag', properties={}), type='TAGGED_WITH', properties={})]
#
#
#  Aura X5 Case
#
# Price: $39.00
#
# Manufacturer: Aura Accessories
#
# Description: Protect your Aura X5 or  === truncated ===
# [Node(id='Cases', type='Category', properties={}), Node(id='Home', type='Segment', properties={}), Node(id='Phone', type='Tag', properties={})]
# []
#
#
# **Product Summary: Aura X5 Starter Kit**
#
# **Description:** Get started with the revolutionary Aura  === truncated ===
# [Node(id='Aura X5 Starter Kit', type='Bundle', properties={'price': '920.00'}), Node(id='Bundles', type='Category', properties={}), Node(id='Home', type='Segment', properties={}), Node(id='Phone', type='Tag', properties={})]
# [Relationship(source=Node(id='Aura X5 Starter Kit', type='Bundle', properties={}), target=Node(id='Phone', type='Tag', properties={}), type='TAGGED_WITH', properties={})]
#
# ,
# Product Summary: Aura X5 Smartphone
#
# Experience the future of mobile technology with the Aura X5.  === truncated ===
# [Node(id='Aura X5 Smartphone', type='Product', properties={'price': '899.00', 'features': 'Long-lasting Battery', 'weight': '205g', 'embedding': '...'}), Node(id='Mobile Phones', type='Category', properties={}), Node(id='Home', type='Segment', properties={}), Node(id='Phone', type='Tag', properties={})]
# [Relationship(source=Node(id='Aura X5 Smartphone', type='Product', properties={}), target=Node(id='Mobile Phones', type='Category', properties={}), type='IN_CATEGORY', properties={}), Relationship(source=Node(id='Aura X5 Smartphone', type='Product', properties={}), target=Node(id='Home', type='Segment', properties={}), type='IN_SEGMENT', properties={}), Relationship(source=Node(id='Aura X5 Smartphone', type='Product', properties={}), target=Node(id='Phone', type='Tag', properties={}), type='TAGGED_WITH', properties={})]
#
#
#   Limited-Time Offer: SkyHawk Zephyr Propeller Guards
#   Fly with Confidence & Save!
#   Deal Price: $ === truncated ===
# [Node(id='Photography', type='Tag', properties={}), Node(id='Videography', type='Tag', properties={}), Node(id='Limited-Time Offer: Skyhawk Zephyr Propeller Guards', type='Deal', properties={'price': '9.99', 'deal_end_date': '2025-05-31'})]
# [Relationship(source=Node(id='Skyhawk Zephyr Propeller Guards', type='Product', properties={}), target=Node(id='Photography', type='Tag', properties={}), type='TAGGED_WITH', properties={}), Relationship(source=Node(id='Skyhawk Zephyr Propeller Guards', type='Product', properties={}), target=Node(id='Videography', type='Tag', properties={}), type='TAGGED_WITH', properties={}), Relationship(source=Node(id='Skyhawk Zephyr Propeller Guards', type='Product', properties={}), target=Node(id='Limited-Time Offer: Skyhawk Zephyr Propeller Guards', type='Deal', properties={}), type='HAS_DEAL', properties={})]
#
#
#   Bunde: SkyHawk Zephyr Explorer Package
#   Price: $179.99
#   Enhance your flight experience with add === truncated ===
# [Node(id='Skyhawk Zephyr Explorer Package', type='Bundle', properties={'price': '179.99'}), Node(id='Photography', type='Tag', properties={}), Node(id='Videography', type='Tag', properties={})]
# [Relationship(source=Node(id='Skyhawk Zephyr Drone', type='Product', properties={}), target=Node(id='Skyhawk Zephyr Explorer Package', type='Bundle', properties={}), type='IN_BUNDLE', properties={}), Relationship(source=Node(id='Skyhawk Zephyr Explorer Package', type='Bundle', properties={}), target=Node(id='Photography', type='Tag', properties={}), type='TAGGED_WITH', properties={}), Relationship(source=Node(id='Skyhawk Zephyr Explorer Package', type='Bundle', properties={}), target=Node(id='Videography', type='Tag', properties={}), type='TAGGED_WITH', properties={})]
#
#
#   Limited-Time Offer: SkyHawk Zephyr Drone
#   Save on your first drone
#   Deal Price: $109.99  (Origi === truncated ===
# [Node(id='Photography', type='Tag', properties={}), Node(id='Videography', type='Tag', properties={}), Node(id='Limited-Time Offer: Skyhawk Zephyr Drone', type='Deal', properties={'deal_end_date': '2025-05-31'})]
# [Relationship(source=Node(id='Skyhawk Zephyr Drone', type='Product', properties={}), target=Node(id='Photography', type='Tag', properties={}), type='TAGGED_WITH', properties={}), Relationship(source=Node(id='Skyhawk Zephyr Drone', type='Product', properties={}), target=Node(id='Videography', type='Tag', properties={}), type='TAGGED_WITH', properties={}), Relationship(source=Node(id='Skyhawk Zephyr Drone', type='Product', properties={}), target=Node(id='Limited-Time Offer: Skyhawk Zephyr Drone', type='Deal', properties={}), type='HAS_DEAL', properties={})]
#
#
#   Bundle:SkyHawk Zephyr Starter Package
#   Price: $129.99
#   Everything you need to begin your drone  === truncated ===
# [Node(id='Skyhawk Zephyr Starter Package', type='Bundle', properties={'price': '129.99'}), Node(id='Photography', type='Tag', properties={}), Node(id='Videography', type='Tag', properties={})]
# [Relationship(source=Node(id='Skyhawk Zephyr Drone', type='Product', properties={}), target=Node(id='Skyhawk Zephyr Starter Package', type='Bundle', properties={}), type='IN_BUNDLE', properties={}), Relationship(source=Node(id='Skyhawk Zephyr Starter Package', type='Bundle', properties={}), target=Node(id='Photography', type='Tag', properties={}), type='TAGGED_WITH', properties={}), Relationship(source=Node(id='Skyhawk Zephyr Starter Package', type='Bundle', properties={}), target=Node(id='Videography', type='Tag', properties={}), type='TAGGED_WITH', properties={})]
#
#
#   Product: SkyHawk Zephyr Propeller Guards
#   Price: $14.99
#   Weight: 20g (0.7 oz)
#   Fly with Confid === truncated ===
# [Node(id='Skyhawk Zephyr Propeller Guards', type='Product', properties={'price': '14.99', 'weight': '20g (0.7 oz)', 'features': 'Increased Durability: Provides an extra layer of protection for your drone.', 'embedding': '...'}), Node(id='Photography', type='Tag', properties={}), Node(id='Videography', type='Tag', properties={})]
# [Relationship(source=Node(id='Skyhawk Zephyr Propeller Guards', type='Product', properties={}), target=Node(id='Skyhawk Zephyr Drone', type='Product', properties={}), type='IS_ACCESSORY_OF', properties={}), Relationship(source=Node(id='Skyhawk Zephyr Propeller Guards', type='Product', properties={}), target=Node(id='Photography', type='Tag', properties={}), type='TAGGED_WITH', properties={}), Relationship(source=Node(id='Skyhawk Zephyr Propeller Guards', type='Product', properties={}), target=Node(id='Videography', type='Tag', properties={}), type='TAGGED_WITH', properties={})]
#
#
#   Product: SkyHawk Zephyr Extended Battery
#   Price: $29.99
#   Weight: 70g (2.5 oz)
#   Fly Longer, Exp === truncated ===
# [Node(id='Skyhawk Zephyr Extended Battery', type='Product', properties={'price': '$29.99', 'weight': '70g (2.5 oz)', 'features': 'Increased Capacity: Enjoy up to 25 minutes of flight time on a single charge, a 67% increase over the standard battery.\nEasy Installation: Seamlessly swap out with the original battery in seconds.\nSafe and Reliable: Built to the same high-quality standards as the SkyHawk Zephyr drone.', 'embedding': '...'}), Node(id='Photography', type='Tag', properties={}), Node(id='Videography', type='Tag', properties={})]
# [Relationship(source=Node(id='Skyhawk Zephyr Extended Battery', type='Product', properties={}), target=Node(id='Skyhawk Zephyr Drone', type='Product', properties={}), type='IS_ACCESSORY_OF', properties={}), Relationship(source=Node(id='Skyhawk Zephyr Extended Battery', type='Product', properties={}), target=Node(id='Photography', type='Tag', properties={}), type='TAGGED_WITH', properties={}), Relationship(source=Node(id='Skyhawk Zephyr Extended Battery', type='Product', properties={}), target=Node(id='Videography', type='Tag', properties={}), type='TAGGED_WITH', properties={})]
#
#
#   Product: SkyHawk Zephyr 2.0 - Reach New Heights
#   Price: $199.99
#   Weight: 250g (8.8 oz)
#   Soar t === truncated ===
# [Node(id='Skyhawk Zephyr 2.0', type='Product', properties={'price': '$199.99', 'weight': '250g (8.8 oz)', 'features': 'Streamlined Design: A sleek and aerodynamic design for improved flight performance.', 'embedding': '...'}), Node(id='Drone', type='Category', properties={}), Node(id='Home', type='Segment', properties={}), Node(id='Photography', type='Tag', properties={}), Node(id='Videography', type='Tag', properties={})]
# [Relationship(source=Node(id='Skyhawk Zephyr 2.0', type='Product', properties={}), target=Node(id='Drone', type='Category', properties={}), type='IN_CATEGORY', properties={}), Relationship(source=Node(id='Skyhawk Zephyr 2.0', type='Product', properties={}), target=Node(id='Home', type='Segment', properties={}), type='IN_SEGMENT', properties={}), Relationship(source=Node(id='Skyhawk Zephyr 2.0', type='Product', properties={}), target=Node(id='Photography', type='Tag', properties={}), type='TAGGED_WITH', properties={}), Relationship(source=Node(id='Skyhawk Zephyr 2.0', type='Product', properties={}), target=Node(id='Videography', type='Tag', properties={}), type='TAGGED_WITH', properties={}), Relationship(source=Node(id='Skyhawk Zephyr 2.0', type='Product', properties={}), target=Node(id='Skyhawk Zephyr Drone', type='Product', properties={}), type='IS_UPGRADE_OF', properties={})]
#
#
#   Product: SkyHawk Zephyr Drone
#   Price: $129.99
#   Weight: 220g (7.8 oz)
#   The SkyHawk Zephyr is th === truncated ===
# [Node(id='Skyhawk Zephyr Drone', type='Product', properties={'price': '129.99', 'weight': '220g (7.8 oz)', 'features': 'Worry-Free Flying: Free Fly mode lets you fly without directional concerns.', 'embedding': '...'}), Node(id='Drone', type='Category', properties={}), Node(id='Home', type='Segment', properties={}), Node(id='Photography', type='Tag', properties={}), Node(id='Videography', type='Tag', properties={})]
# [Relationship(source=Node(id='Skyhawk Zephyr Drone', type='Product', properties={}), target=Node(id='Drone', type='Category', properties={}), type='IN_CATEGORY', properties={}), Relationship(source=Node(id='Skyhawk Zephyr Drone', type='Product', properties={}), target=Node(id='Home', type='Segment', properties={}), type='IN_SEGMENT', properties={}), Relationship(source=Node(id='Skyhawk Zephyr Drone', type='Product', properties={}), target=Node(id='Photography', type='Tag', properties={}), type='TAGGED_WITH', properties={}), Relationship(source=Node(id='Skyhawk Zephyr Drone', type='Product', properties={}), target=Node(id='Videography', type='Tag', properties={}), type='TAGGED_WITH', properties={})]
#
#
# Office Bundle
#
# Price: $1600
#
# Manufacturer: Aura Systems
#
# Description: Enhance your productivity wit === truncated ===
# [Node(id='Office Bundle', type='Bundle', properties={'price': '1600'}), Node(id='Bundles', type='Category', properties={}), Node(id='Home', type='Segment', properties={}), Node(id='Office', type='Segment', properties={}), Node(id='Computer', type='Tag', properties={})]
# [Relationship(source=Node(id='Aurabook Air', type='Product', properties={}), target=Node(id='Office Bundle', type='Bundle', properties={}), type='IN_BUNDLE', properties={}), Relationship(source=Node(id='Office Bundle', type='Bundle', properties={}), target=Node(id='Computer', type='Tag', properties={}), type='TAGGED_WITH', properties={})]
#
#
# **Product Summary: AuraBook Air**
#
# Stay productive on the move with the AuraBook Air, a lightweight === truncated ===
# [Node(id='Aurabook Air', type='Product', properties={'price': '999.00', 'features': 'Sleek, modern design', 'embedding': '...'}), Node(id='Laptops', type='Category', properties={}), Node(id='Home', type='Segment', properties={}), Node(id='Office', type='Segment', properties={}), Node(id='Computer', type='Tag', properties={})]
# [Relationship(source=Node(id='Aurabook Air', type='Product', properties={}), target=Node(id='Laptops', type='Category', properties={}), type='IN_CATEGORY', properties={}), Relationship(source=Node(id='Aurabook Air', type='Product', properties={}), target=Node(id='Home', type='Segment', properties={}), type='IN_SEGMENT', properties={}), Relationship(source=Node(id='Aurabook Air', type='Product', properties={}), target=Node(id='Office', type='Segment', properties={}), type='IN_SEGMENT', properties={}), Relationship(source=Node(id='Aurabook Air', type='Product', properties={}), target=Node(id='Computer', type='Tag', properties={}), type='TAGGED_WITH', properties={})]
#
#
# **Product Summary: AuraView 32 Pro**
#
# Immerse yourself in stunning visuals with the AuraView 32 Pro === truncated ===
# [Node(id='Auraview 32 Pro', type='Product', properties={'price': '599.99', 'features': 'Built-in Speakers', 'embedding': '...'}), Node(id='Monitors', type='Category', properties={}), Node(id='Home', type='Segment', properties={}), Node(id='Office', type='Segment', properties={}), Node(id='Computer', type='Tag', properties={})]
# [Relationship(source=Node(id='Auraview 32 Pro', type='Product', properties={}), target=Node(id='Monitors', type='Category', properties={}), type='IN_CATEGORY', properties={}), Relationship(source=Node(id='Auraview 32 Pro', type='Product', properties={}), target=Node(id='Home', type='Segment', properties={}), type='IN_SEGMENT', properties={}), Relationship(source=Node(id='Auraview 32 Pro', type='Product', properties={}), target=Node(id='Office', type='Segment', properties={}), type='IN_SEGMENT', properties={}), Relationship(source=Node(id='Auraview 32 Pro', type='Product', properties={}), target=Node(id='Computer', type='Tag', properties={}), type='TAGGED_WITH', properties={})]
#
#
# Product Summary: Quantum Charger
#
# Stay powered up and ready to go with the Quantum Charger, designe === truncated ===
# [Node(id='Quantum Charger', type='Product', properties={'price': '69.00', 'weight': '0.25 lbs', 'features': 'LED Indicator Light', 'embedding': '...'}), Node(id='Accessories', type='Category', properties={}), Node(id='Home', type='Segment', properties={}), Node(id='Office', type='Segment', properties={}), Node(id='Computer', type='Tag', properties={})]
# [Relationship(source=Node(id='Quantum Charger', type='Product', properties={}), target=Node(id='Accessories', type='Category', properties={}), type='IN_CATEGORY', properties={}), Relationship(source=Node(id='Quantum Charger', type='Product', properties={}), target=Node(id='Home', type='Segment', properties={}), type='IN_SEGMENT', properties={}), Relationship(source=Node(id='Quantum Charger', type='Product', properties={}), target=Node(id='Office', type='Segment', properties={}), type='IN_SEGMENT', properties={}), Relationship(source=Node(id='Quantum Charger', type='Product', properties={}), target=Node(id='Computer', type='Tag', properties={}), type='TAGGED_WITH', properties={})]
#
#
# Dual Monitor Productivity Bundle
#
# Price: $849.99
#
# Manufacturer: Aura Displays
#
# Description: Superch === truncated ===
# [Node(id='Dual Monitor Productivity Bundle', type='Bundle', properties={'price': '849.99'}), Node(id='Bundles', type='Category', properties={}), Node(id='Home', type='Segment', properties={}), Node(id='Office', type='Segment', properties={}), Node(id='Computer', type='Tag', properties={})]
# [Relationship(source=Node(id='Dual Monitor Productivity Bundle', type='Bundle', properties={}), target=Node(id='Computer', type='Tag', properties={}), type='TAGGED_WITH', properties={})]
#
#
# Product Summary: SecureView Privacy Screen
#
# Price: $79.00
#
# Manufacturer: AuraTech (Designed for Aur === truncated ===
# [Node(id='Laptop Privacy Screen', type='Category', properties={}), Node(id='Home', type='Segment', properties={}), Node(id='Office', type='Segment', properties={}), Node(id='Computer', type='Tag', properties={})]
# []
#
#
# Product Summary:
#
# Product Name: Blue Light Filter Screen
#
# Price: $39.99
#
# Description: Combat eye st === truncated ===
# [Node(id='Blue Light Filter Screen', type='Product', properties={'price': '39.99', 'features': 'Lightweight and Durable', 'weight': '1.2 lbs', 'embedding': '...'}), Node(id='Accessories', type='Category', properties={}), Node(id='Home', type='Segment', properties={}), Node(id='Office', type='Segment', properties={}), Node(id='Computer', type='Tag', properties={})]
# [Relationship(source=Node(id='Blue Light Filter Screen', type='Product', properties={}), target=Node(id='Accessories', type='Category', properties={}), type='IN_CATEGORY', properties={}), Relationship(source=Node(id='Blue Light Filter Screen', type='Product', properties={}), target=Node(id='Home', type='Segment', properties={}), type='IN_SEGMENT', properties={}), Relationship(source=Node(id='Blue Light Filter Screen', type='Product', properties={}), target=Node(id='Office', type='Segment', properties={}), type='IN_SEGMENT', properties={}), Relationship(source=Node(id='Blue Light Filter Screen', type='Product', properties={}), target=Node(id='Computer', type='Tag', properties={}), type='TAGGED_WITH', properties={}), Relationship(source=Node(id='Blue Light Filter Screen', type='Product', properties={}), target=Node(id='Auraview 32 Pro', type='Product', properties={}), type='IS_ACCESSORY_OF', properties={})]
#
#
# ErgoFlex Pro - Premium Monitor Arm
#
# Price: $149.99
#
# Manufacturer: FlexiTech Solutions
#
# Description: === truncated ===
# [Node(id='Monitor Arms', type='Category', properties={}), Node(id='Home', type='Segment', properties={}), Node(id='Office', type='Segment', properties={}), Node(id='Computer', type='Tag', properties={})]
# []
#
#
# VESA Mount Adapter
#
# Price: $19.99
#
# Description: Easily adapt monitors without standard VESA mountin === truncated ===
# [Node(id='Vesa Mount Adapter', type='Product', properties={'price': '19.99', 'features': 'Low Profile Design: Minimizes the distance between the monitor and mount.', 'embedding': '...'}), Node(id='Accessories', type='Category', properties={}), Node(id='Home', type='Segment', properties={}), Node(id='Office', type='Segment', properties={}), Node(id='Computer', type='Tag', properties={})]
# [Relationship(source=Node(id='Vesa Mount Adapter', type='Product', properties={}), target=Node(id='Accessories', type='Category', properties={}), type='IN_CATEGORY', properties={}), Relationship(source=Node(id='Vesa Mount Adapter', type='Product', properties={}), target=Node(id='Home', type='Segment', properties={}), type='IN_SEGMENT', properties={}), Relationship(source=Node(id='Vesa Mount Adapter', type='Product', properties={}), target=Node(id='Office', type='Segment', properties={}), type='IN_SEGMENT', properties={}), Relationship(source=Node(id='Vesa Mount Adapter', type='Product', properties={}), target=Node(id='Computer', type='Tag', properties={}), type='TAGGED_WITH', properties={})]
#
#
# Lumix Keyboard
#
# Price: $129.00
#
# Manufacturer: Lumix Tech
#
# Description: Experience unparalleled comf === truncated ===
# [Node(id='Accessories', type='Category', properties={}), Node(id='Home', type='Segment', properties={}), Node(id='Office', type='Segment', properties={}), Node(id='Computer', type='Tag', properties={})]
# []
#
#
# Product Summary: AuraView 32 Curved Monitor
#
# Immerse yourself in stunning visuals with the AuraView === truncated ===
# [Node(id='Monitors', type='Category', properties={}), Node(id='Home', type='Segment', properties={}), Node(id='Office', type='Segment', properties={}), Node(id='Computer', type='Tag', properties={})]
# []
#
#
# **Product Summary: Summer Savings Deal - AuraView 32" LED TV**
#
# **Headline:** Save Big This Summer  === truncated ===
# [Node(id='Summer Savings Deal', type='Deal', properties={'deal_end_date': '2024-07-31'}), Node(id='Home', type='Segment', properties={}), Node(id='Office', type='Segment', properties={}), Node(id='Computer', type='Tag', properties={})]
# []
#
#
# Cable Management Kit
#
# Price: $29.99
#
# Manufacturer: ErgoDynamics
#
# Description: Eliminate cable clutt === truncated ===
# [Node(id='Cable Management Kit', type='Product', properties={'price': '29.99', 'weight': '0.25 lbs', 'features': 'Comprehensive Kit: Includes cable ties, cable clips, and a flexible cable sleeve.\nEasy Installation: Simple, tool-free installation using adhesive backing and adjustable straps.\nDurable Materials: Made from high-quality, long-lasting materials for reliable performance.\nSleek Design: Aesthetically pleasing design that complements any office environment.\nReusable and Adjustable: Reconfigure your cable management as needed.', 'embedding': '...'}), Node(id='Accessories', type='Category', properties={}), Node(id='Home', type='Segment', properties={}), Node(id='Office', type='Segment', properties={}), Node(id='Computer', type='Tag', properties={})]
# [Relationship(source=Node(id='Cable Management Kit', type='Product', properties={}), target=Node(id='Accessories', type='Category', properties={}), type='IN_CATEGORY', properties={}), Relationship(source=Node(id='Cable Management Kit', type='Product', properties={}), target=Node(id='Home', type='Segment', properties={}), type='IN_SEGMENT', properties={}), Relationship(source=Node(id='Cable Management Kit', type='Product', properties={}), target=Node(id='Office', type='Segment', properties={}), type='IN_SEGMENT', properties={}), Relationship(source=Node(id='Cable Management Kit', type='Product', properties={}), target=Node(id='Computer', type='Tag', properties={}), type='TAGGED_WITH', properties={})]
#
#
# Privacy Protection Bundle
#
# Price: $1550.00
#
# Manufacturer: Aura Technologies (AuraBook Air) & Secure === truncated ===
# [Node(id='Privacy Protection Bundle', type='Bundle', properties={'price': '1550.00'}), Node(id='Bundles', type='Category', properties={}), Node(id='Home', type='Segment', properties={}), Node(id='Office', type='Segment', properties={}), Node(id='Computer', type='Tag', properties={})]
# [Relationship(source=Node(id='Aurabook Air', type='Product', properties={}), target=Node(id='Privacy Protection Bundle', type='Bundle', properties={}), type='IN_BUNDLE', properties={}), Relationship(source=Node(id='Privacy Protection Bundle', type='Bundle', properties={}), target=Node(id='Computer', type='Tag', properties={}), type='TAGGED_WITH', properties={})]
#
#
# Product Summary: PrivacyGuard Pro
#
# Shield your screen from prying eyes and protect yourself from ha === truncated ===
# [Node(id='Privacyguard Pro', type='Product', properties={'price': '99.00', 'features': 'Case-Friendly Design: Compatible with most AuraBook X500 cases.', 'weight': '25g', 'embedding': '...'}), Node(id='Laptop Privacy Screen', type='Category', properties={}), Node(id='Home', type='Segment', properties={}), Node(id='Office', type='Segment', properties={}), Node(id='Computer', type='Tag', properties={})]
# [Relationship(source=Node(id='Privacyguard Pro', type='Product', properties={}), target=Node(id='Laptop Privacy Screen', type='Category', properties={}), type='IN_CATEGORY', properties={}), Relationship(source=Node(id='Privacyguard Pro', type='Product', properties={}), target=Node(id='Home', type='Segment', properties={}), type='IN_SEGMENT', properties={}), Relationship(source=Node(id='Privacyguard Pro', type='Product', properties={}), target=Node(id='Office', type='Segment', properties={}), type='IN_SEGMENT', properties={}), Relationship(source=Node(id='Privacyguard Pro', type='Product', properties={}), target=Node(id='Computer', type='Tag', properties={}), type='TAGGED_WITH', properties={})]
#
#
# PrivacyGuard Standard
#
# Price: $49.00
#
# Manufacturer: Privacy Solutions Inc.
#
# Description: Keep your  === truncated ===
# [Node(id='Accessories', type='Category', properties={}), Node(id='Home', type='Segment', properties={}), Node(id='Office', type='Segment', properties={}), Node(id='Computer', type='Tag', properties={})]
# []
#
#
# **AuraBook X500 Deal - Limited Time Offer!**
#
# **Price:** $1400.00
#
# **Manufacturer:** Aura Technolog === truncated ===
# [Node(id='Aurabook X500 Deal', type='Deal', properties={'deal_end_date': '2024-03-15', 'price': '1400.00'}), Node(id='Home', type='Segment', properties={}), Node(id='Office', type='Segment', properties={}), Node(id='Computer', type='Tag', properties={})]
# []
#
#
# **Ergonomic Workstation Bundle: AuraView 32 + ErgoFlex Pro**
#
# **Price:** $649.99
#
# **Manufacturer:** === truncated ===
# [Node(id='Ergonomic Workstation Bundle', type='Bundle', properties={'price': '649.99'}), Node(id='Bundles', type='Category', properties={}), Node(id='Home', type='Segment', properties={}), Node(id='Office', type='Segment', properties={}), Node(id='Computer', type='Tag', properties={})]
# [Relationship(source=Node(id='Ergonomic Workstation Bundle', type='Bundle', properties={}), target=Node(id='Computer', type='Tag', properties={}), type='TAGGED_WITH', properties={})]
#
#
# ## AuraBook X500 - Quantum Leaps in Performance
#
# **Product Summary:**
#
# Experience the future of com === truncated ===
# [Node(id='Laptops', type='Category', properties={}), Node(id='Home', type='Segment', properties={}), Node(id='Office', type='Segment', properties={}), Node(id='Computer', type='Tag', properties={})]
# []
#
#
#  ChromaClean Kit
#
# Price: $29.99
#
# Manufacturer: Chroma Solutions
#
# Description: Maintain peak perform === truncated ===
# [Node(id='Chroma Solutions', type='Category', properties={'name': 'Chroma Solutions'}), Node(id='Printing', type='Tag', properties={'name': 'Printing'})]
# []
#
#
# ChromaJet Pro XL
#
# Price: $799.00
#
# Manufacturer: ChromaTech
#
# Description: Unlock professional-grade  === truncated ===
# [Node(id='Chromatech', type='Category', properties={'name': 'Printer'}), Node(id='Home', type='Segment', properties={'name': 'Home'}), Node(id='Office', type='Segment', properties={'name': 'Office'}), Node(id='Printing', type='Tag', properties={'name': 'Printing'})]
# [Relationship(source=Node(id='Chromajet Pro Xl', type='Product', properties={}), target=Node(id='Chromatech', type='Category', properties={}), type='IN_CATEGORY', properties={}), Relationship(source=Node(id='Chromajet Pro Xl', type='Product', properties={}), target=Node(id='Home', type='Segment', properties={}), type='IN_SEGMENT', properties={}), Relationship(source=Node(id='Chromajet Pro Xl', type='Product', properties={}), target=Node(id='Office', type='Segment', properties={}), type='IN_SEGMENT', properties={}), Relationship(source=Node(id='Chromajet Pro Xl', type='Product', properties={}), target=Node(id='Printing', type='Tag', properties={}), type='TAGGED_WITH', properties={}), Relationship(source=Node(id='Chromajet Pro Xl', type='Product', properties={}), target=Node(id='Chromajet Pro', type='Product', properties={}), type='IS_UPGRADE_OF', properties={}), Relationship(source=Node(id='Chromashield Laminator', type='Product', properties={}), target=Node(id='Chromajet Pro Xl', type='Product', properties={}), type='IS_ACCESSORY_OF', properties={})]
#
#
#  ChromaJet Starter Bundle
#
# Price: $528.00
#
# Manufacturer: ChromaCorp
#
# Description: Get started with  === truncated ===
# [Node(id='Chromajet Starter Bundle', type='Bundle', properties={'price': '528.00'}), Node(id='Printing', type='Tag', properties={})]
# [Relationship(source=Node(id='Chromajet Pro', type='Product', properties={}), target=Node(id='Chromajet Starter Bundle', type='Bundle', properties={}), type='IN_BUNDLE', properties={}), Relationship(source=Node(id='Chromajet Starter Bundle', type='Bundle', properties={}), target=Node(id='Printing', type='Tag', properties={}), type='TAGGED_WITH', properties={})]
#
#
# ChromaClean Kit
#
# Price: $29.99
#
# Manufacturer: Chroma Solutions
#
# Description: Maintain peak performa === truncated ===
# [Node(id='Printing', type='Tag', properties={})]
# []
#
#
#  ChromaJet Pro
#
# Price: $499.00
#
# Manufacturer: Pixel Perfect Technologies
#
# Description: Experience v === truncated ===
# [Node(id='Chromajet Pro', type='Product', properties={'price': '499.00', 'features': 'Large Paper Capacity: 250-sheet input tray minimizes refills.', 'embedding': '...'}), Node(id='Printer', type='Category', properties={}), Node(id='Home', type='Segment', properties={}), Node(id='Office', type='Segment', properties={}), Node(id='Printing', type='Tag', properties={})]
# [Relationship(source=Node(id='Chromajet Pro', type='Product', properties={}), target=Node(id='Printer', type='Category', properties={}), type='IN_CATEGORY', properties={}), Relationship(source=Node(id='Chromajet Pro', type='Product', properties={}), target=Node(id='Home', type='Segment', properties={}), type='IN_SEGMENT', properties={}), Relationship(source=Node(id='Chromajet Pro', type='Product', properties={}), target=Node(id='Office', type='Segment', properties={}), type='IN_SEGMENT', properties={}), Relationship(source=Node(id='Chromajet Pro', type='Product', properties={}), target=Node(id='Printing', type='Tag', properties={}), type='TAGGED_WITH', properties={}), Relationship(source=Node(id='Chromashield Laminator', type='Product', properties={}), target=Node(id='Chromajet Pro', type='Product', properties={}), type='IS_ACCESSORY_OF', properties={})]
#
#
# Deal: ChromaJet Pro XL Early Bird
#
# Price: $749.00
#
# Manufacturer: ChromaTech
#
# Description: Don't mis === truncated ===
# [Node(id='Chromajet Pro Xl Early Bird', type='Deal', properties={'price': '$749.00', 'deal_end_date': '2024-03-15'}), Node(id='Chromajet Pro Xl', type='Product', properties={'name': 'ChromaJet Pro XL', 'features': 'Automatic duplex printing: Save paper with automatic two-sided printing', 'weight': '14.3 lbs', 'embedding': '...'}), Node(id='Printing', type='Tag', properties={})]
# [Relationship(source=Node(id='Chromajet Pro Xl', type='Product', properties={}), target=Node(id='Chromajet Pro Xl Early Bird', type='Deal', properties={}), type='HAS_DEAL', properties={}), Relationship(source=Node(id='Chromajet Pro Xl', type='Product', properties={}), target=Node(id='Printing', type='Tag', properties={}), type='TAGGED_WITH', properties={})]
#
#
# **Product Summary: ChromaJet Pro XL Studio Bundle**
#
# Elevate your print production with the ChromaJ === truncated ===
# [Node(id='Chromajet Pro Xl Studio Bundle', type='Bundle', properties={'price': '928.00'}), Node(id='Printing', type='Tag', properties={})]
# [Relationship(source=Node(id='Chromashield Laminator', type='Product', properties={}), target=Node(id='Chromajet Pro Xl Studio Bundle', type='Bundle', properties={}), type='IN_BUNDLE', properties={}), Relationship(source=Node(id='Chromajet Pro Xl Studio Bundle', type='Bundle', properties={}), target=Node(id='Printing', type='Tag', properties={}), type='TAGGED_WITH', properties={})]
#
#
#  ChromaJet Pro XL Early Bird
#
# Price: $749.00
#
# Manufacturer: ChromaTech
#
# Description: Don't miss out === truncated ===
# [Node(id='Chromajet Pro Xl Early Bird', type='Product', properties={'price': '749.00', 'deal_end_date': '2024-03-15', 'features': 'Automatic duplex printing: Save paper with automatic two-sided printing', 'weight': '14.3 lbs', 'embedding': '...'}), Node(id='Printing', type='Tag', properties={})]
# [Relationship(source=Node(id='Chromajet Pro Xl Early Bird', type='Product', properties={}), target=Node(id='Printing', type='Tag', properties={}), type='TAGGED_WITH', properties={})]
#
#
# ChromaShield Laminator
#
# Price: $149.00
#
# Protect your valuable prints from fading, scratches, and mo === truncated ===
# [Node(id='Chromashield Laminator', type='Product', properties={'price': '149.00', 'weight': '5 lbs', 'features': 'User-Friendly Controls', 'embedding': '...'}), Node(id='Printing', type='Tag', properties={})]
# [Relationship(source=Node(id='Chromashield Laminator', type='Product', properties={}), target=Node(id='Chromajet Pro', type='Product', properties={}), type='IS_ACCESSORY_OF', properties={}), Relationship(source=Node(id='Chromashield Laminator', type='Product', properties={}), target=Node(id='Printing', type='Tag', properties={}), type='TAGGED_WITH', properties={})]
#
#
# ChromaJet Starter Bundle
#
# Price: $528.00
#
# Manufacturer: ChromaCorp
#
# Description: Get started with e === truncated ===
# [Node(id='Chromajet Starter Bundle', type='Bundle', properties={'price': '528.00'}), Node(id='Printing', type='Tag', properties={})]
# [Relationship(source=Node(id='Chromajet Pro', type='Product', properties={}), target=Node(id='Chromajet Starter Bundle', type='Bundle', properties={}), type='IN_BUNDLE', properties={}), Relationship(source=Node(id='Chromajet Starter Bundle', type='Bundle', properties={}), target=Node(id='Printing', type='Tag', properties={}), type='TAGGED_WITH', properties={})]
#
#
#  **Product Summary: ChromaJet Pro XL Studio Bundle**
#
# Elevate your print production with the Chroma === truncated ===
# [Node(id='Chromajet Pro Xl Studio Bundle', type='Bundle', properties={'price': '928.00'}), Node(id='Printing', type='Tag', properties={})]
# [Relationship(source=Node(id='Chromashield Laminator', type='Product', properties={}), target=Node(id='Chromajet Pro Xl Studio Bundle', type='Bundle', properties={}), type='IN_BUNDLE', properties={}), Relationship(source=Node(id='Chromajet Pro Xl Studio Bundle', type='Bundle', properties={}), target=Node(id='Printing', type='Tag', properties={}), type='TAGGED_WITH', properties={})]
#
#
# ChromaPaper Pro Pack
#
# Price: $49.99
#
# Description: Achieve exceptional print quality with the Chroma === truncated ===
# [Node(id='Printing', type='Tag', properties={})]
# []
#
#
#  ChromaJet Pro XL
#
# Price: $799.00
#
# Manufacturer: ChromaTech
#
# Description: Unlock professional-grade === truncated ===
# [Node(id='Chromatech', type='Category', properties={'name': 'Printer'}), Node(id='Home', type='Segment', properties={'name': 'Home'}), Node(id='Office', type='Segment', properties={'name': 'Office'}), Node(id='Printing', type='Tag', properties={'name': 'Printing'})]
# [Relationship(source=Node(id='Chromajet Pro Xl', type='Product', properties={}), target=Node(id='Chromatech', type='Category', properties={}), type='IN_CATEGORY', properties={}), Relationship(source=Node(id='Chromajet Pro Xl', type='Product', properties={}), target=Node(id='Home', type='Segment', properties={}), type='IN_SEGMENT', properties={}), Relationship(source=Node(id='Chromajet Pro Xl', type='Product', properties={}), target=Node(id='Office', type='Segment', properties={}), type='IN_SEGMENT', properties={}), Relationship(source=Node(id='Chromajet Pro Xl', type='Product', properties={}), target=Node(id='Printing', type='Tag', properties={}), type='TAGGED_WITH', properties={}), Relationship(source=Node(id='Chromajet Pro Xl', type='Product', properties={}), target=Node(id='Chromajet Pro', type='Product', properties={}), type='IS_UPGRADE_OF', properties={}), Relationship(source=Node(id='Chromashield Laminator', type='Product', properties={}), target=Node(id='Chromajet Pro Xl', type='Product', properties={}), type='IS_ACCESSORY_OF', properties={})]
#
#
#  ChromaShield Laminator
#
# Price: $149.00
#
# Protect your valuable prints from fading, scratches, and m === truncated ===
# [Node(id='Chromashield Laminator', type='Product', properties={'price': '149.00', 'features': 'User-Friendly Controls', 'weight': '5 lbs', 'embedding': '...'}), Node(id='Printing', type='Tag', properties={})]
# [Relationship(source=Node(id='Chromashield Laminator', type='Product', properties={}), target=Node(id='Chromajet Pro', type='Product', properties={}), type='IS_ACCESSORY_OF', properties={}), Relationship(source=Node(id='Chromashield Laminator', type='Product', properties={}), target=Node(id='Printing', type='Tag', properties={}), type='TAGGED_WITH', properties={})]
#
#
#  ChromaPaper Pro Pack
#
# Price: $49.99
#
# Description: Achieve exceptional print quality with the Chrom === truncated ===
# [Node(id='Printing', type='Tag', properties={})]
# []
#
#
# ChromaJet Pro
#
# Price: $499.00
#
# Manufacturer: Pixel Perfect Technologies
#
# Description: Experience vi === truncated ===
# [Node(id='Printer', type='Category', properties={}), Node(id='Home', type='Segment', properties={}), Node(id='Office', type='Segment', properties={}), Node(id='Printing', type='Tag', properties={})]
# [Relationship(source=Node(id='Chromajet Pro', type='Product', properties={}), target=Node(id='Printer', type='Category', properties={}), type='IN_CATEGORY', properties={}), Relationship(source=Node(id='Chromajet Pro', type='Product', properties={}), target=Node(id='Home', type='Segment', properties={}), type='IN_SEGMENT', properties={}), Relationship(source=Node(id='Chromajet Pro', type='Product', properties={}), target=Node(id='Office', type='Segment', properties={}), type='IN_SEGMENT', properties={}), Relationship(source=Node(id='Chromajet Pro', type='Product', properties={}), target=Node(id='Printing', type='Tag', properties={}), type='TAGGED_WITH', properties={}), Relationship(source=Node(id='Chromashield Laminator', type='Product', properties={}), target=Node(id='Chromajet Pro', type='Product', properties={}), type='IS_ACCESSORY_OF', properties={})]
#
#
#   Bundle: SnapShot Voyager Creative Studio Kit
#   Price: $349.99
#   Everything you need to expand you === truncated ===
# [Node(id='Snapshot Voyager Creative Studio Kit', type='Bundle', properties={'price': '349.99'}), Node(id='Photography', type='Tag', properties={})]
# [Relationship(source=Node(id='Snapshot Voyager Camera 3.0', type='Product', properties={}), target=Node(id='Snapshot Voyager Creative Studio Kit', type='Bundle', properties={}), type='IN_BUNDLE', properties={}), Relationship(source=Node(id='Snapshot Voyager Creative Studio Kit', type='Bundle', properties={}), target=Node(id='Photography', type='Tag', properties={}), type='TAGGED_WITH', properties={})]
#
#
#   Bundle: SnapShot Voyager Photography Essentials
#   Price: $299.99
#   Everything you need to start c === truncated ===
# [Node(id='Snapshot Voyager Photography Essentials', type='Bundle', properties={'price': '299.99'}), Node(id='Photography', type='Tag', properties={})]
# [Relationship(source=Node(id='Snapshot Voyager Camera 3.0', type='Product', properties={}), target=Node(id='Snapshot Voyager Photography Essentials', type='Bundle', properties={}), type='IN_BUNDLE', properties={}), Relationship(source=Node(id='Snapshot Voyager Photography Essentials', type='Bundle', properties={}), target=Node(id='Photography', type='Tag', properties={}), type='TAGGED_WITH', properties={})]
#
#
#   Product: SnapShot Voyager Remote Shutter Release
#   Price: $24.99
#   Weight: 40g (1.4 oz)
#   Capture === truncated ===
# [Node(id='Snapshot Voyager Remote Shutter Release', type='Product', properties={'price': '24.99', 'weight': '40g (1.4 oz)', 'features': "Easy Connection: Plugs directly into the camera's remote port for quick and simple setup.", 'embedding': '...'}), Node(id='Photography', type='Tag', properties={})]
# [Relationship(source=Node(id='Snapshot Voyager Remote Shutter Release', type='Product', properties={}), target=Node(id='Snapshot Voyager Camera 3.0', type='Product', properties={}), type='IS_ACCESSORY_OF', properties={}), Relationship(source=Node(id='Snapshot Voyager Remote Shutter Release', type='Product', properties={}), target=Node(id='Photography', type='Tag', properties={}), type='TAGGED_WITH', properties={})]
#
#
#   Product: SnapShot Voyager Lens Hood
#   Price: $19.99
#   Weight: 30g (1.1 oz)
#   Capture Images with  === truncated ===
# [Node(id='Snapshot Voyager Lens Hood', type='Product', properties={'price': '19.99', 'weight': '30g (1.1 oz)', 'features': 'Easy Attachment: Screws securely onto the lens for a snug and reliable fit.', 'embedding': '...'}), Node(id='Photography', type='Tag', properties={})]
# [Relationship(source=Node(id='Snapshot Voyager Lens Hood', type='Product', properties={}), target=Node(id='Snapshot Voyager Camera 3.0', type='Product', properties={}), type='IS_ACCESSORY_OF', properties={}), Relationship(source=Node(id='Snapshot Voyager Lens Hood', type='Product', properties={}), target=Node(id='Photography', type='Tag', properties={}), type='TAGGED_WITH', properties={})]
#
#
#   Limited-Time Offer: SnapShot Voyager Remote Shutter Release
#   Capture Blur-Free Images & Save!
#    === truncated ===
# [Node(id='Deal', type='Deal', properties={'deal_end_date': '2025-02-28'}), Node(id='Photography', type='Tag', properties={})]
# [Relationship(source=Node(id='Snapshot Voyager Remote Shutter Release', type='Product', properties={}), target=Node(id='Deal', type='Deal', properties={}), type='HAS_DEAL', properties={}), Relationship(source=Node(id='Snapshot Voyager Remote Shutter Release', type='Product', properties={}), target=Node(id='Photography', type='Tag', properties={}), type='TAGGED_WITH', properties={})]
#
#
#   Product: SnapShot Voyager Camera 3.0
#   Price: $249.99
#   Weight: 350g (12.3 oz)
#   Capture Your Wor === truncated ===
# [Node(id='Snapshot Voyager Camera 3.0', type='Product', properties={'price': '249.99', 'weight': '350g (12.3 oz)', 'features': 'Long Battery Life', 'embedding': '...'}), Node(id='Camera', type='Category', properties={}), Node(id='Home', type='Segment', properties={}), Node(id='Photography', type='Tag', properties={})]
# [Relationship(source=Node(id='Snapshot Voyager Camera 3.0', type='Product', properties={}), target=Node(id='Camera', type='Category', properties={}), type='IN_CATEGORY', properties={}), Relationship(source=Node(id='Snapshot Voyager Camera 3.0', type='Product', properties={}), target=Node(id='Home', type='Segment', properties={}), type='IN_SEGMENT', properties={}), Relationship(source=Node(id='Snapshot Voyager Camera 3.0', type='Product', properties={}), target=Node(id='Photography', type='Tag', properties={}), type='TAGGED_WITH', properties={})]

# %% [markdown]
# ### Load data to Spanner Graph

# %%
# Uncomment the line below, if you want to cleanup from previous iterations.
# BeWARE - THIS COULD REMOVE DATA FROM YOUR DATABASE !!!
graph_store.cleanup()
graph_store.add_graph_documents(graph_documents)
# Out:
# Waiting for DDL operations to complete...
# Waiting for DDL operations to complete...
# Insert nodes of type `Deal`...
# Insert nodes of type `Deal`...
# Insert nodes of type `Tag`...
# Insert nodes of type `Tag`...
# Insert nodes of type `Bundle`...
# Insert nodes of type `Category`...
# Insert nodes of type `Category`...
# Insert nodes of type `Product`...
# Insert nodes of type `Product`...
# Insert nodes of type `Product`...
# Insert nodes of type `Product`...
# Insert nodes of type `Segment`...
# Insert edges of type `Product_IN_BUNDLE_Bundle`...
# Insert edges of type `Bundle_TAGGED_WITH_Tag`...
# Insert edges of type `Product_IN_CATEGORY_Category`...
# Insert edges of type `Product_IN_SEGMENT_Segment`...
# Insert edges of type `Product_TAGGED_WITH_Tag`...
# Insert edges of type `Product_IS_ACCESSORY_OF_Product`...
# Insert edges of type `Deal_TAGGED_WITH_Tag`...
# Insert edges of type `Product_HAS_DEAL_Deal`...
# Insert edges of type `Product_IS_UPGRADE_OF_Product`...

# %% [markdown]
# ## Visualization

# %%
# %load_ext spanner_graphs

# %%
# %%spanner_graph --project {PROJECT_ID} --instance {INSTANCE} --database {DATABASE}
#
# GRAPH retail_graph
# MATCH p = ()->()
# RETURN TO_JSON(p) AS path_json

# %% [markdown]
# ## GraphRAG flow using Spanner Graph

# %% [markdown]
# ### Question Answering Prompt

# %%
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts.prompt import PromptTemplate
from langchain_google_vertexai import ChatVertexAI, VertexAIEmbeddings

from IPython.display import Markdown
import textwrap


# Retrieve and generate using the relevant snippets of the blog.
def format_docs(docs):
    print("Context Retrieved: \n")
    for doc in docs:
        print(textwrap.fill(doc.page_content, width=80))
        print("\n")

    context = "\n\n".join(doc.page_content for doc in docs)
    return context


SPANNERGRAPH_QA_TEMPLATE = """
You are a helpful and friendly AI assistant for question answering tasks for an electronics
retail online store.
Create a human readable answer for the for the question.
You should only use the information provided in the context and not use your internal knowledge.
Don't add any information.
Here is an example:

Question: Which funds own assets over 10M?
Context:[name:ABC Fund, name:Star fund]"
Helpful Answer: ABC Fund and Star fund have assets over 10M.

Follow this example when generating answers.
You are given the following information:
- `Question`: the natural language question from the user
- `Graph Schema`: contains the schema of the graph database
- `Graph Query`: A Spanner Graph GQL query equivalent of the question from the user used to extract context from the graph database
- `Context`: The response from the graph database as context. The context has nodes and edges. Use the relationships.
Information:
Question: {question}
Graph Schema: {graph_schema}
Context: {context}

Format your answer to be human readable.
Use the relationships in the context to answer the question.
Only include information that is relevant to a customer.
Helpful Answer:"""

prompt = PromptTemplate(
    template=SPANNERGRAPH_QA_TEMPLATE,
    input_variables=["question", "graph_schema", "context"],
)

llm = ChatVertexAI(model="gemini-2.5-flash", temperature=0)

chain = prompt | llm | StrOutputParser()

# %% [markdown]
# ### GraphRAG using Vector Search and Graph Expansion

# %%
from langchain_google_spanner import SpannerGraphVectorContextRetriever
from langchain_google_vertexai import VertexAIEmbeddings


def use_node_vector_retriever(
    question, graph_store, embedding_service, label_expr, expand_by_hops
):
    retriever = SpannerGraphVectorContextRetriever.from_params(
        graph_store=graph_store,
        embedding_service=embedding_service,
        label_expr=label_expr,
        expand_by_hops=expand_by_hops,
        top_k=1,
        k=10,
    )
    context = format_docs(retriever.invoke(question))
    return context


embedding_service = VertexAIEmbeddings(model_name="text-embedding-005")

# %%
# Enable Debugging on LangChain
from langchain.globals import set_debug
# set_debug(True)

# %%
import textwrap

question = "Give me recommendations for a beginner drone"
context = use_node_vector_retriever(
    question, graph_store, embedding_service, label_expr="Product", expand_by_hops=1
)

answer = chain.invoke(
    {"question": question, "graph_schema": graph_store.get_schema, "context": context}
)

print("\n\nAnswer:\n")
print(textwrap.fill(answer, width=80))
# Out:
# Context Retrieved:
#
# [{"element_definition_name": "Product", "kind": "node", "labels": ["Product"],
# "properties": {"deal_end_date": null, "features": "Increased Durability:
# Provides an extra layer of protection for your drone.", "id": "Skyhawk Zephyr
# Propeller Guards", "name": null, "price": "14.99", "weight": "20g (0.7 oz)"}}]
#
#
# [{"element_definition_name": "Product", "kind": "node", "labels": ["Product"],
# "properties": {"deal_end_date": null, "features": "Increased Durability:
# Provides an extra layer of protection for your drone.", "id": "Skyhawk Zephyr
# Propeller Guards", "name": null, "price": "14.99", "weight": "20g (0.7 oz)"}},
# {"element_definition_name": "Product_HAS_DEAL_Deal", "kind": "edge", "labels":
# ["Product_HAS_DEAL_Deal"], "properties": {"id": "Skyhawk Zephyr Propeller
# Guards", "target_id": "Limited-Time Offer: Skyhawk Zephyr Propeller Guards"}},
# {"element_definition_name": "Deal", "kind": "node", "labels": ["Deal"],
# "properties": {"deal_end_date": "2025-05-31", "id": "Limited-Time Offer: Skyhawk
# Zephyr Propeller Guards", "price": "9.99"}}]
#
#
# [{"element_definition_name": "Product", "kind": "node", "labels": ["Product"],
# "properties": {"deal_end_date": null, "features": "Increased Durability:
# Provides an extra layer of protection for your drone.", "id": "Skyhawk Zephyr
# Propeller Guards", "name": null, "price": "14.99", "weight": "20g (0.7 oz)"}},
# {"element_definition_name": "Product_IS_ACCESSORY_OF_Product", "kind": "edge",
# "labels": ["Product_IS_ACCESSORY_OF_Product"], "properties": {"id": "Skyhawk
# Zephyr Propeller Guards", "target_id": "Skyhawk Zephyr Drone"}},
# {"element_definition_name": "Product", "kind": "node", "labels": ["Product"],
# "properties": {"deal_end_date": null, "features": "Worry-Free Flying: Free Fly
# mode lets you fly without directional concerns.", "id": "Skyhawk Zephyr Drone",
# "name": null, "price": "129.99", "weight": "220g (7.8 oz)"}}]
#
#
# [{"element_definition_name": "Product", "kind": "node", "labels": ["Product"],
# "properties": {"deal_end_date": null, "features": "Increased Durability:
# Provides an extra layer of protection for your drone.", "id": "Skyhawk Zephyr
# Propeller Guards", "name": null, "price": "14.99", "weight": "20g (0.7 oz)"}},
# {"element_definition_name": "Product_TAGGED_WITH_Tag", "kind": "edge", "labels":
# ["Product_TAGGED_WITH_Tag"], "properties": {"id": "Skyhawk Zephyr Propeller
# Guards", "target_id": "Photography"}}, {"element_definition_name": "Tag",
# "kind": "node", "labels": ["Tag"], "properties": {"id": "Photography", "name":
# null}}]
#
#
# [{"element_definition_name": "Product", "kind": "node", "labels": ["Product"],
# "properties": {"deal_end_date": null, "features": "Increased Durability:
# Provides an extra layer of protection for your drone.", "id": "Skyhawk Zephyr
# Propeller Guards", "name": null, "price": "14.99", "weight": "20g (0.7 oz)"}},
# {"element_definition_name": "Product_TAGGED_WITH_Tag", "kind": "edge", "labels":
# ["Product_TAGGED_WITH_Tag"], "properties": {"id": "Skyhawk Zephyr Propeller
# Guards", "target_id": "Videography"}}, {"element_definition_name": "Tag",
# "kind": "node", "labels": ["Tag"], "properties": {"id": "Videography", "name":
# null}}]
#
#
#
#
# Answer:
#
# For a beginner drone, we recommend the **Skyhawk Zephyr Drone**. It features
# "Worry-Free Flying" with a Free Fly mode that lets you fly without directional
# concerns, making it easier for new users. It is priced at $129.99.  You might
# also consider the **Skyhawk Zephyr Propeller Guards** as an accessory for
# increased durability and an extra layer of protection for your drone. These are
# currently on a limited-time offer for $9.99, down from $14.99, until May 31,
# 2025.

# %% [markdown]
# ## Compare with Conventional RAG

# %%
# Define table name
TABLE_NAME = "retail_table"  # @param {"type":"string"}

# %% [markdown]
# ### Setup and load data for vector search

# %%
from langchain_google_spanner import SpannerVectorStore
from langchain_google_vertexai import VertexAIEmbeddings
from langchain_text_splitters import RecursiveCharacterTextSplitter

import uuid


def load_data_for_vector_search(splits, embeddings):
    SpannerVectorStore.init_vector_store_table(
        instance_id=INSTANCE,
        database_id=DATABASE,
        table_name=TABLE_NAME,
    )
    db = SpannerVectorStore(
        instance_id=INSTANCE,
        database_id=DATABASE,
        table_name=TABLE_NAME,
        embedding_service=embeddings,
    )
    # Add the chunks to Spanner Vector Store with embeddings
    ids = [str(uuid.uuid4()) for _ in range(len(splits))]
    row_ids = db.add_documents(splits, ids)
    return len(row_ids)


# Create splits for documents
text_splitter = RecursiveCharacterTextSplitter(chunk_size=2000, chunk_overlap=200)
splits = text_splitter.split_documents(
    [document for document_list in document_lists for document in document_list]
)

# Initialize table and load data
embeddings = VertexAIEmbeddings(model_name="text-embedding-005")
num_docs = load_data_for_vector_search(splits, embeddings)

# %% [markdown]
# ### Create a conventional RAG chain

# %%
from langchain_core.runnables import RunnablePassthrough
from langchain_google_spanner import SpannerVectorStore
import textwrap


# Retrieve and generate using the relevant snippets of the blog.
def format_docs(docs):
    print("Context Retrieved: \n")
    for doc in docs:
        print(textwrap.fill(doc.page_content, width=80))
        print("\n")

    context = "\n\n".join(doc.page_content for doc in docs)
    return context


prompt = PromptTemplate(
    template="""
    You are a friendly digital shopping assistant.
    Use the following pieces of retrieved context to answer the question.
    If you don't know the answer, just say that you don't know.
    Question: {question}
    Context: {context}
    Answer:
  """,
    input_variables=["context", "question"],
)

# Create a rag chain
embeddings = VertexAIEmbeddings(model_name="text-embedding-005")

db = SpannerVectorStore(
    instance_id=INSTANCE,
    database_id=DATABASE,
    table_name=TABLE_NAME,
    embedding_service=embeddings,
)
vector_retriever = db.as_retriever(search_kwargs={"k": 3})
rag_chain = (
    {
        "context": vector_retriever | format_docs,
        "question": RunnablePassthrough(),
    }
    | prompt
    | llm
    | StrOutputParser()
)

# %% [markdown]
# ### Run conventional RAG chain

# %%
import textwrap

question = "I am looking for an beginner drone. Please give me some recommendations."
resp = rag_chain.invoke(question)

print("\n\nRag Response:\n")
print(textwrap.fill(resp, width=80))
# Out:
# Context Retrieved:
#
# Product: SkyHawk Zephyr Drone   Price: $129.99   Weight: 220g (7.8 oz)   The
# SkyHawk Zephyr is the perfect drone for beginners. It's built for effortless
# flying, offering a smooth and enjoyable experience from the moment you unpack
# it.   Features:   Simple Controls: Beginner friendly and intuitive controls,
# plus automatic takeoff and landing.   Tough Build: Designed to handle rookie
# mistakes, thanks to its robust construction.   Capture Memories: Record crisp HD
# photos and videos from above.   Extended Fun: Enjoy up to 15 minutes of flight
# time per charge.   Worry-Free Flying: Free Fly mode lets you fly without
# directional concerns.   Take your first flight with the SkyHawk Zephyr and
# discover the joy of aerial views!    Category: Drone   Segment: ['Home']   Tags:
# ['Photography', 'Videography']
#
#
# Bundle:SkyHawk Zephyr Starter Package   Price: $129.99   Everything you need to
# begin your drone journey:   This package includes the essentials to get you
# flying and capturing stunning aerial footage. Perfect for first-time pilots who
# want a user-friendly and reliable drone.   Package Includes:   SkyHawk Zephyr
# Drone   Remote Controller   Rechargeable Battery   USB Charging Cable   Spare
# Propellers   User Manual   Take flight with the SkyHawk Zephyr Starter Package!
# Tags: ['Photography', 'Videography']
#
#
# Limited-Time Offer: SkyHawk Zephyr Drone   Save on your first drone   Deal
# Price: $109.99  (Original Price: $129.99)   Offer valid till 31st May 2025 or
# while supplies last.   Tags: ['Photography', 'Videography']
#
#
#
#
# Rag Response:
#
# I recommend the **SkyHawk Zephyr Drone** for beginners!  It's specifically
# designed for effortless flying and a smooth experience. Here's why it's a great
# choice:  *   **Simple Controls:** It has beginner-friendly and intuitive
# controls, including automatic takeoff and landing. *   **Tough Build:** Designed
# to handle rookie mistakes, making it durable for new pilots. *   **Capture
# Memories:** You can record crisp HD photos and videos. *   **Extended Fun:**
# Enjoy up to 15 minutes of flight time per charge. *   **Worry-Free Flying:** Its
# Free Fly mode lets you fly without directional concerns.  There's also a
# **Limited-Time Offer** where you can get the SkyHawk Zephyr Drone for
# **$109.99** (originally $129.99). This offer is valid until May 31st, 2025, or
# while supplies last.  You can also consider the **SkyHawk Zephyr Starter
# Package** for $129.99, which includes the drone, remote controller, rechargeable
# battery, USB charging cable, spare propellers, and a user manual – everything
# you need to get started!

# %% [markdown]
# #### Clean up the graph
#
# > USE IT WITH CAUTION!
#
# Clean up all the nodes/edges in your graph and remove your graph definition.

# %%
graph_store.cleanup()
